# %% [markdown]
# ### Создаем эмулятор среды ShootEnv для генерации начальных условий угла и дальности цели, а также для выдачи наград за удачные попадания.
# ### Награда распределена по нормальному распределению в радиусе, задаваемому в конструкторе класса

# %%
import numpy as np
import scipy.stats as sps

import random
from hashlib import md5
import time


class ShootEnv:
    def __init__(self, low=0, high=1000, eps=0.1, scale=1.0, radius=1.0, reward_type="norm"):
        self.eps = eps
        self.alpha = 0
        self.s = 0
        self.g = 9.8
        self.scale = scale
        self.radius = radius
        self.reward_type = reward_type
        self.low = low
        self.high = high
        

    def reset(self):
        self.alpha = np.random.uniform(low=self.eps, high=np.pi / 2 - self.eps, size=1)[0]
        self.s = np.random.uniform(low=self.low, high=self.high, size=1)[0]
        return [self.alpha, self.s]

    def step(self, action):
        s_calc = action ** 2 * np.sin(2 * self.alpha) / self.g
        if self.reward_type == "norm":
            reward = sps.norm.pdf(s_calc, loc=self.s, scale=self.scale) * 10 if np.abs(self.s - s_calc) <= self.radius else 0
        elif self.reward_type == "uniform":
            reward = 1 if np.abs(self.s - s_calc) <= self.radius else 0
        else:
            pass
        return [-1, -1], reward, True, {"real_s": s_calc}

# %% [markdown]
# #### Для решения задачи используется алгоритм Deep Deterministic Policy (DDPG), позволяющий решать задачи в непрерывных пространствах действий.

# %%
import torch
import torch.nn as nn

from torch.optim import Adam

torch.set_grad_enabled(True)


class DDPGAgent(nn.Module):
    def __init__(self, state_dim=2, action_dim=1, q_lr=1e-3, pi_lr=1e-3, batch_size=64, sigma=6.0, episode_n=1_000_000):
        super().__init__()
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.q = nn.Sequential(
            nn.Linear(state_dim + action_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

        for module in self.q:
            if isinstance(module, nn.Linear):
                nn.init.kaiming_normal_(module.weight, nonlinearity="relu")

        self.pi = nn.Sequential(
            nn.Linear(state_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, action_dim),
            nn.Sigmoid()
        )

        for module in self.pi:
            if isinstance(module, nn.Linear):
                nn.init.kaiming_normal_(module.weight, nonlinearity="relu")

        self.q_lr = q_lr
        self.pi_lr = pi_lr
        self.q_optimizer = Adam(self.q.parameters(), q_lr)
        self.pi_optimizer = Adam(self.pi.parameters(), pi_lr)
        self.q_scheduler = torch.optim.lr_scheduler.MultiStepLR(self.q_optimizer, milestones=[int(0.25*episode_n), int(0.6*episode_n), int(0.85*episode_n)], gamma=0.5)
        self.pi_scheduler = torch.optim.lr_scheduler.MultiStepLR(self.pi_optimizer, milestones=[int(0.3*episode_n), int(0.5*episode_n), int(0.7*episode_n), int(0.9*episode_n)], gamma=0.5)

        self.buffer = []
        self.batch_size = batch_size
        self.init_sigma = sigma
        self.sigma = sigma
        self.sigma_decay = 0.99995
        self.min_sigma = 0.1
        self.step = 0
        self.epsilon = 0
        self.alpha = 0.5
        self.init_N = 25
        self.N = self.init_N
        self.S = 20
        self.episode_n = episode_n
        # ширина диапазона возможных значений будет (0, range)
        self.range = 100

    def decay_sigma(self):
        if self.step % (self.episode_n // 4) == 0:
            self.sigma = self.init_sigma / 2
        self.sigma = max(self.sigma * self.sigma_decay, self.min_sigma)

    def decay_N(self):
        if self.step % (self.episode_n // 3) == 0:
            self.N = self.N - 5

    def decay_alpha(self):
        if self.step % (self.episode_n // 3) == 0:
            self.alpha = self.alpha * 0.75

    def disable_grads(self, net):
        for param in net.parameters():
            param.requires_grad = False

    def enable_grads(self, net):
        for param in net.parameters():
            param.requires_grad = True

    def get_action(self, obs):
        with torch.no_grad():
            obs = torch.tensor(obs, dtype=torch.float)
            # домножаем на self.range чтобы получить нужное значение
            action = self.pi(obs).numpy()[0] * self.range
            # orshteine ulunbek
            self.epsilon = self.alpha * self.epsilon + np.random.normal(loc=0, scale=self.sigma)
            noisy_action = action + self.epsilon
            return noisy_action

    def add_sample(self, state, action, reward):
        #print(state, action, reward)
        # self.buffer.append([state, [action], [reward]])
        if self.step % self.S == 0:
            self.buffer.append([state, [action], [reward]])
            
    def fit(self):
        if len(self.buffer) > self.batch_size:
            batch = random.sample(self.buffer, self.batch_size)
            states, actions, rewards = map(torch.FloatTensor, list(zip(*batch)))

            if self.step % self.N == 0:
                max_actions = self.pi(states)
                # print(max_actions.requires_grad)
                states_actions = torch.concatenate((states, max_actions), dim=1)
    
                # grads for pi model
                self.disable_grads(self.q)
                
                pi_loss = -1.0 * torch.mean(self.q(states_actions))

                pi_loss.backward()
                
                self.pi_optimizer.step()
                self.pi_optimizer.zero_grad()
    
                self.enable_grads(self.q)

            # grads for q model
            targets = rewards

            states_actions = torch.concatenate((states, actions), dim=1)
            q_loss = torch.mean((self.q(states_actions) - targets.detach())**2)
            q_loss.backward()
            self.q_optimizer.step()
            self.q_optimizer.zero_grad()
            self.step += 1
            self.decay_sigma()
            self.decay_N()
            self.decay_alpha()

            self.q_scheduler.step()
            self.pi_scheduler.step()

    def save_model(self, path=f'/home/artem/atari_games/models/DDPG_{md5(str(time.time()).encode()).hexdigest()}.pth'):
        state = {
            'q_model_dict': self.q.state_dict(),
            'pi_model_dict': self.pi.state_dict(),
            'q_optimizer_dict': self.q_optimizer.state_dict(),
            'pi_optimizer_dict': self.pi_optimizer.state_dict(),
            'epsilon': self.epsilon,
            'alpha': self.alpha,
            'sigma': self.sigma
        }
        torch.save(state, path)

    def load_model(self,path=f'/home/artem/atari_games/models/DDPG_{md5(str(time.time()).encode()).hexdigest()}'):
        if os.path.exists(path):
            state = torch.load(path)
            self.optimizer.load_state_dict(state['optimizer_dict'])
            self.q_function.load_state_dict(state['model_dict'])
            self.target_q_function.load_state_dict(state['model_dict'])
            self.epsilon = state['epsilon']

# %%
### текущие гиперпараметры  q_lr=1e-3, pi_lr=1e-4, batch_size=64, sigma=3.0 self.sigma_decay = 0.9995
# self.min_sigma = 0.8
# self.step = 0
# self.epsilon = 0
# self.alpha = 0.5
# self.N = 30
# self.S = 20

# Увеличил немного pi_lr, добавил lr_decay, увеличил время эксплорэйшна для сигмы, увеличил размеры нейросети c 32 до 64.Зафиксировал seed
# Q - функция выучена судя по нескольким примерам и довольно хорошо. Наименьший средний скор 2.5. Но агент не везде успевает выучиться.

# Пробую увеличить lr для агента. И увеличить частоту его обучения. self.N = 20. (Возможно еще попробую увеличить batch_size, но попозже)
# Увеличил пространство возможных значений для s. Не успел доучиться. Дошел до 1_000_000, но еще был потенциал к падению ошибки.

# В итоге лучшим остался скор 2.5 

# Исследования происходят волнообразно. И быстрее убывает сигма. В результате это позволяет выбираться из локальных минимумов. Увеличение батча не сработало.
# Пробую уменьшить альфу и выставить минимальную сигму поменьше.

# %% [markdown]
# #### Запускаю алгоритм на полтора миллиона итераций. Качество оцениваю по среднему и медианному расстоянию снаряда до цели. Также оцениваю полученнную награду.

# %%
torch.manual_seed(42)

env = ShootEnv(high=100, radius=1.0, reward_type="norm")

episode_n = 3_000_000

agent = DDPGAgent(episode_n=episode_n)
average = []
rewards = 0
k = 0
for i in range(episode_n):
    state = env.reset()
    
    for _ in range(10):
        action = agent.get_action(state)
        next_state, reward, done, info = env.step(action)
        rewards += reward
        agent.add_sample(state, action, reward)
        agent.fit()
        average.append(abs(state[1] - info["real_s"]))
        if i % 1000 == 0:
            print(f'iteration: {k}, avg dist {np.round(np.mean(average), 3)}, \
            median dist {np.round(np.median(average), 3)} sum of rewards={np.round(rewards, 3)}, \
            buffer len = {len(agent.buffer)}, sanity_check last_action={round(action, 3)}')
            k += 1
            average = []
            rewards = 0
        if done:
            break
# Out:
# iteration: 0, avg dist 3.206,             median dist 3.206 sum of rewards=0,             buffer len = 1, sanity_check last_action=1.115
# iteration: 1, avg dist 29.517,             median dist 23.67 sum of rewards=105.463,             buffer len = 111, sanity_check last_action=41.645
# iteration: 2, avg dist 36.863,             median dist 21.152 sum of rewards=84.804,             buffer len = 161, sanity_check last_action=0.802
# iteration: 3, avg dist 42.136,             median dist 19.905 sum of rewards=126.081,             buffer len = 211, sanity_check last_action=4.107
# iteration: 4, avg dist 33.654,             median dist 20.144 sum of rewards=109.637,             buffer len = 261, sanity_check last_action=42.102
# iteration: 5, avg dist 35.127,             median dist 18.956 sum of rewards=142.226,             buffer len = 311, sanity_check last_action=54.385
# iteration: 6, avg dist 34.717,             median dist 18.154 sum of rewards=128.914,             buffer len = 361, sanity_check last_action=22.608
# iteration: 7, avg dist 32.763,             median dist 16.879 sum of rewards=85.541,             buffer len = 411, sanity_check last_action=20.372
# iteration: 8, avg dist 97.49,             median dist 48.1 sum of rewards=132.6,             buffer len = 461, sanity_check last_action=25.562
# iteration: 9, avg dist 81.062,             median dist 37.415 sum of rewards=175.969,             buffer len = 511, sanity_check last_action=34.958
# iteration: 10, avg dist 91.602,             median dist 49.691 sum of rewards=126.381,             buffer len = 561, sanity_check last_action=38.035
# iteration: 11, avg dist 66.425,             median dist 29.671 sum of rewards=145.778,             buffer len = 611, sanity_check last_action=20.981
# iteration: 12, avg dist 38.866,             median dist 19.432 sum of rewards=157.263,             buffer len = 661, sanity_check last_action=24.345
# iteration: 13, avg dist 39.268,             median dist 19.423 sum of rewards=176.464,             buffer len = 711, sanity_check last_action=49.602
# iteration: 14, avg dist 56.274,             median dist 28.499 sum of rewards=130.465,             buffer len = 761, sanity_check last_action=9.334
# iteration: 15, avg dist 34.926,             median dist 18.382 sum of rewards=185.731,             buffer len = 811, sanity_check last_action=12.248
# iteration: 16, avg dist 37.13,             median dist 18.842 sum of rewards=175.389,             buffer len = 861, sanity_check last_action=48.101
# iteration: 17, avg dist 50.277,             median dist 20.063 sum of rewards=176.63,             buffer len = 911, sanity_check last_action=21.409
# iteration: 18, avg dist 47.598,             median dist 21.847 sum of rewards=168.08,             buffer len = 961, sanity_check last_action=34.009
# iteration: 19, avg dist 39.528,             median dist 19.474 sum of rewards=180.732,             buffer len = 1011, sanity_check last_action=16.085
# iteration: 20, avg dist 39.229,             median dist 19.076 sum of rewards=155.781,             buffer len = 1061, sanity_check last_action=13.191
# iteration: 21, avg dist 40.266,             median dist 20.079 sum of rewards=160.301,             buffer len = 1111, sanity_check last_action=31.571
# iteration: 22, avg dist 37.771,             median dist 19.972 sum of rewards=171.932,             buffer len = 1161, sanity_check last_action=40.373
# iteration: 23, avg dist 43.618,             median dist 21.333 sum of rewards=139.857,             buffer len = 1211, sanity_check last_action=12.924
# iteration: 24, avg dist 47.826,             median dist 21.999 sum of rewards=184.877,             buffer len = 1261, sanity_check last_action=58.515
# iteration: 25, avg dist 49.329,             median dist 23.039 sum of rewards=176.274,             buffer len = 1311, sanity_check last_action=25.061
# iteration: 26, avg dist 59.809,             median dist 31.387 sum of rewards=177.587,             buffer len = 1361, sanity_check last_action=35.943
# iteration: 27, avg dist 40.258,             median dist 19.246 sum of rewards=196.979,             buffer len = 1411, sanity_check last_action=23.857
# iteration: 28, avg dist 37.124,             median dist 16.506 sum of rewards=222.409,             buffer len = 1461, sanity_check last_action=25.926
# iteration: 29, avg dist 41.396,             median dist 21.133 sum of rewards=174.272,             buffer len = 1511, sanity_check last_action=20.439
# iteration: 30, avg dist 40.292,             median dist 20.311 sum of rewards=236.026,             buffer len = 1561, sanity_check last_action=17.199
# iteration: 31, avg dist 36.521,             median dist 18.347 sum of rewards=267.947,             buffer len = 1611, sanity_check last_action=48.838
# iteration: 32, avg dist 34.42,             median dist 16.655 sum of rewards=280.203,             buffer len = 1661, sanity_check last_action=53.153
# iteration: 33, avg dist 37.328,             median dist 20.488 sum of rewards=191.415,             buffer len = 1711, sanity_check last_action=51.147
# iteration: 34, avg dist 32.396,             median dist 15.699 sum of rewards=236.531,             buffer len = 1761, sanity_check last_action=28.448
# iteration: 35, avg dist 38.18,             median dist 18.986 sum of rewards=223.284,             buffer len = 1811, sanity_check last_action=52.593
# iteration: 36, avg dist 35.097,             median dist 17.101 sum of rewards=245.569,             buffer len = 1861, sanity_check last_action=6.356
# iteration: 37, avg dist 35.212,             median dist 15.987 sum of rewards=277.935,             buffer len = 1911, sanity_check last_action=51.008
# iteration: 38, avg dist 39.987,             median dist 20.05 sum of rewards=247.77,             buffer len = 1961, sanity_check last_action=55.825
# iteration: 39, avg dist 37.659,             median dist 16.536 sum of rewards=241.687,             buffer len = 2011, sanity_check last_action=39.139
# iteration: 40, avg dist 35.595,             median dist 16.939 sum of rewards=275.303,             buffer len = 2061, sanity_check last_action=39.688
# iteration: 41, avg dist 31.92,             median dist 16.099 sum of rewards=267.903,             buffer len = 2111, sanity_check last_action=18.993
# iteration: 42, avg dist 33.629,             median dist 16.278 sum of rewards=243.618,             buffer len = 2161, sanity_check last_action=7.058
# iteration: 43, avg dist 33.589,             median dist 16.696 sum of rewards=250.11,             buffer len = 2211, sanity_check last_action=22.1
# iteration: 44, avg dist 36.85,             median dist 17.023 sum of rewards=206.717,             buffer len = 2261, sanity_check last_action=19.022
# iteration: 45, avg dist 35.689,             median dist 16.187 sum of rewards=272.038,             buffer len = 2311, sanity_check last_action=43.627
# iteration: 46, avg dist 36.199,             median dist 17.879 sum of rewards=202.202,             buffer len = 2361, sanity_check last_action=21.275
# iteration: 47, avg dist 40.124,             median dist 19.89 sum of rewards=236.137,             buffer len = 2411, sanity_check last_action=4.203
# iteration: 48, avg dist 42.738,             median dist 20.997 sum of rewards=256.551,             buffer len = 2461, sanity_check last_action=51.222
# iteration: 49, avg dist 39.434,             median dist 19.198 sum of rewards=294.088,             buffer len = 2511, sanity_check last_action=34.622
# iteration: 50, avg dist 36.243,             median dist 16.773 sum of rewards=288.722,             buffer len = 2561, sanity_check last_action=32.078
# iteration: 51, avg dist 33.446,             median dist 16.309 sum of rewards=320.861,             buffer len = 2611, sanity_check last_action=16.186
# iteration: 52, avg dist 43.578,             median dist 20.239 sum of rewards=242.107,             buffer len = 2661, sanity_check last_action=41.48
# iteration: 53, avg dist 38.551,             median dist 18.765 sum of rewards=311.481,             buffer len = 2711, sanity_check last_action=21.05
# iteration: 54, avg dist 35.649,             median dist 17.353 sum of rewards=270.24,             buffer len = 2761, sanity_check last_action=40.067
# iteration: 55, avg dist 37.03,             median dist 18.015 sum of rewards=255.21,             buffer len = 2811, sanity_check last_action=8.122
# iteration: 56, avg dist 36.77,             median dist 18.08 sum of rewards=291.908,             buffer len = 2861, sanity_check last_action=30.68
# iteration: 57, avg dist 35.908,             median dist 16.435 sum of rewards=283.532,             buffer len = 2911, sanity_check last_action=29.5
# iteration: 58, avg dist 40.769,             median dist 18.552 sum of rewards=255.652,             buffer len = 2961, sanity_check last_action=45.048
# iteration: 59, avg dist 37.857,             median dist 18.987 sum of rewards=321.832,             buffer len = 3011, sanity_check last_action=37.187
# iteration: 60, avg dist 40.087,             median dist 17.768 sum of rewards=250.36,             buffer len = 3061, sanity_check last_action=46.796
# iteration: 61, avg dist 38.441,             median dist 17.639 sum of rewards=211.201,             buffer len = 3111, sanity_check last_action=33.066
# iteration: 62, avg dist 37.748,             median dist 18.584 sum of rewards=269.249,             buffer len = 3161, sanity_check last_action=50.609
# iteration: 63, avg dist 36.065,             median dist 15.249 sum of rewards=295.634,             buffer len = 3211, sanity_check last_action=17.617
# iteration: 64, avg dist 38.33,             median dist 17.159 sum of rewards=297.402,             buffer len = 3261, sanity_check last_action=46.75
# iteration: 65, avg dist 40.583,             median dist 19.728 sum of rewards=263.232,             buffer len = 3311, sanity_check last_action=42.679
# iteration: 66, avg dist 37.404,             median dist 17.515 sum of rewards=299.658,             buffer len = 3361, sanity_check last_action=19.982
# iteration: 67, avg dist 45.369,             median dist 20.747 sum of rewards=293.631,             buffer len = 3411, sanity_check last_action=48.337
# iteration: 68, avg dist 35.589,             median dist 17.786 sum of rewards=255.626,             buffer len = 3461, sanity_check last_action=38.259
# iteration: 69, avg dist 47.991,             median dist 20.26 sum of rewards=269.397,             buffer len = 3511, sanity_check last_action=43.568
# iteration: 70, avg dist 39.146,             median dist 18.202 sum of rewards=226.764,             buffer len = 3561, sanity_check last_action=16.295
# iteration: 71, avg dist 43.974,             median dist 21.422 sum of rewards=250.017,             buffer len = 3611, sanity_check last_action=52.269
# iteration: 72, avg dist 51.713,             median dist 23.757 sum of rewards=240.67,             buffer len = 3661, sanity_check last_action=42.485
# iteration: 73, avg dist 43.056,             median dist 20.538 sum of rewards=279.155,             buffer len = 3711, sanity_check last_action=17.086
# iteration: 74, avg dist 46.513,             median dist 20.774 sum of rewards=271.479,             buffer len = 3761, sanity_check last_action=23.376
# iteration: 75, avg dist 50.552,             median dist 20.207 sum of rewards=298.989,             buffer len = 3811, sanity_check last_action=39.651
# iteration: 76, avg dist 58.374,             median dist 22.008 sum of rewards=257.943,             buffer len = 3861, sanity_check last_action=17.408
# iteration: 77, avg dist 44.144,             median dist 20.847 sum of rewards=279.892,             buffer len = 3911, sanity_check last_action=33.646
# iteration: 78, avg dist 42.346,             median dist 19.187 sum of rewards=320.351,             buffer len = 3961, sanity_check last_action=43.212
# iteration: 79, avg dist 38.733,             median dist 17.08 sum of rewards=342.439,             buffer len = 4011, sanity_check last_action=33.165
# iteration: 80, avg dist 39.638,             median dist 19.066 sum of rewards=320.716,             buffer len = 4061, sanity_check last_action=40.727
# iteration: 81, avg dist 46.191,             median dist 21.92 sum of rewards=284.023,             buffer len = 4111, sanity_check last_action=7.87
# iteration: 82, avg dist 39.27,             median dist 17.301 sum of rewards=324.947,             buffer len = 4161, sanity_check last_action=55.268
# iteration: 83, avg dist 39.793,             median dist 18.219 sum of rewards=384.322,             buffer len = 4211, sanity_check last_action=35.471
# iteration: 84, avg dist 51.453,             median dist 20.143 sum of rewards=259.507,             buffer len = 4261, sanity_check last_action=50.612
# iteration: 85, avg dist 40.6,             median dist 18.787 sum of rewards=367.552,             buffer len = 4311, sanity_check last_action=21.923
# iteration: 86, avg dist 37.992,             median dist 18.908 sum of rewards=236.029,             buffer len = 4361, sanity_check last_action=52.438
# iteration: 87, avg dist 40.714,             median dist 18.922 sum of rewards=353.538,             buffer len = 4411, sanity_check last_action=19.085
# iteration: 88, avg dist 42.274,             median dist 19.429 sum of rewards=281.936,             buffer len = 4461, sanity_check last_action=24.743
# iteration: 89, avg dist 36.831,             median dist 15.972 sum of rewards=305.561,             buffer len = 4511, sanity_check last_action=53.321
# iteration: 90, avg dist 35.881,             median dist 16.839 sum of rewards=312.242,             buffer len = 4561, sanity_check last_action=21.451
# iteration: 91, avg dist 39.034,             median dist 17.682 sum of rewards=269.275,             buffer len = 4611, sanity_check last_action=19.916
# iteration: 92, avg dist 33.204,             median dist 15.097 sum of rewards=347.506,             buffer len = 4661, sanity_check last_action=21.513
# iteration: 93, avg dist 38.942,             median dist 18.68 sum of rewards=327.828,             buffer len = 4711, sanity_check last_action=16.407
# iteration: 94, avg dist 41.799,             median dist 20.312 sum of rewards=375.324,             buffer len = 4761, sanity_check last_action=4.254
# iteration: 95, avg dist 42.051,             median dist 19.925 sum of rewards=278.646,             buffer len = 4811, sanity_check last_action=32.313
# iteration: 96, avg dist 46.135,             median dist 21.415 sum of rewards=293.485,             buffer len = 4861, sanity_check last_action=21.801
# iteration: 97, avg dist 42.629,             median dist 19.125 sum of rewards=314.286,             buffer len = 4911, sanity_check last_action=13.194
# iteration: 98, avg dist 38.846,             median dist 16.935 sum of rewards=397.178,             buffer len = 4961, sanity_check last_action=32.14
# iteration: 99, avg dist 35.333,             median dist 16.623 sum of rewards=354.406,             buffer len = 5011, sanity_check last_action=49.821
# iteration: 100, avg dist 35.966,             median dist 17.909 sum of rewards=293.321,             buffer len = 5061, sanity_check last_action=12.863
# iteration: 101, avg dist 34.705,             median dist 16.445 sum of rewards=321.31,             buffer len = 5111, sanity_check last_action=43.8
# iteration: 102, avg dist 32.45,             median dist 14.936 sum of rewards=364.915,             buffer len = 5161, sanity_check last_action=41.549
# iteration: 103, avg dist 43.038,             median dist 19.126 sum of rewards=353.891,             buffer len = 5211, sanity_check last_action=22.384
# iteration: 104, avg dist 41.102,             median dist 18.858 sum of rewards=382.096,             buffer len = 5261, sanity_check last_action=36.659
# iteration: 105, avg dist 36.489,             median dist 18.268 sum of rewards=335.515,             buffer len = 5311, sanity_check last_action=8.47
# iteration: 106, avg dist 39.543,             median dist 18.89 sum of rewards=352.411,             buffer len = 5361, sanity_check last_action=34.703
# iteration: 107, avg dist 37.47,             median dist 19.318 sum of rewards=349.63,             buffer len = 5411, sanity_check last_action=47.723
# iteration: 108, avg dist 59.477,             median dist 21.968 sum of rewards=322.096,             buffer len = 5461, sanity_check last_action=43.108
# iteration: 109, avg dist 30.795,             median dist 15.284 sum of rewards=353.242,             buffer len = 5511, sanity_check last_action=37.061
# iteration: 110, avg dist 39.249,             median dist 18.446 sum of rewards=374.376,             buffer len = 5561, sanity_check last_action=28.986
# iteration: 111, avg dist 30.312,             median dist 13.285 sum of rewards=382.73,             buffer len = 5611, sanity_check last_action=42.12
# iteration: 112, avg dist 34.93,             median dist 16.951 sum of rewards=350.129,             buffer len = 5661, sanity_check last_action=13.48
# iteration: 113, avg dist 35.234,             median dist 16.438 sum of rewards=305.762,             buffer len = 5711, sanity_check last_action=36.035
# iteration: 114, avg dist 33.548,             median dist 14.304 sum of rewards=415.047,             buffer len = 5761, sanity_check last_action=29.675
# iteration: 115, avg dist 39.699,             median dist 17.716 sum of rewards=381.477,             buffer len = 5811, sanity_check last_action=6.125
# iteration: 116, avg dist 36.261,             median dist 16.334 sum of rewards=426.372,             buffer len = 5861, sanity_check last_action=20.63
# iteration: 117, avg dist 29.825,             median dist 13.547 sum of rewards=368.198,             buffer len = 5911, sanity_check last_action=44.13
# iteration: 118, avg dist 35.003,             median dist 15.647 sum of rewards=352.575,             buffer len = 5961, sanity_check last_action=25.72
# iteration: 119, avg dist 33.594,             median dist 14.999 sum of rewards=418.688,             buffer len = 6011, sanity_check last_action=9.753
# iteration: 120, avg dist 36.023,             median dist 16.107 sum of rewards=404.822,             buffer len = 6061, sanity_check last_action=45.691
# iteration: 121, avg dist 35.785,             median dist 15.297 sum of rewards=362.43,             buffer len = 6111, sanity_check last_action=45.529
# iteration: 122, avg dist 39.987,             median dist 16.004 sum of rewards=347.976,             buffer len = 6161, sanity_check last_action=33.705
# iteration: 123, avg dist 36.061,             median dist 16.898 sum of rewards=435.332,             buffer len = 6211, sanity_check last_action=7.031
# iteration: 124, avg dist 35.707,             median dist 16.846 sum of rewards=380.656,             buffer len = 6261, sanity_check last_action=39.602
# iteration: 125, avg dist 33.22,             median dist 16.308 sum of rewards=466.503,             buffer len = 6311, sanity_check last_action=45.611
# iteration: 126, avg dist 36.742,             median dist 14.837 sum of rewards=432.897,             buffer len = 6361, sanity_check last_action=44.745
# iteration: 127, avg dist 34.67,             median dist 15.511 sum of rewards=464.17,             buffer len = 6411, sanity_check last_action=12.726
# iteration: 128, avg dist 35.354,             median dist 15.466 sum of rewards=418.424,             buffer len = 6461, sanity_check last_action=9.82
# iteration: 129, avg dist 37.12,             median dist 17.008 sum of rewards=424.16,             buffer len = 6511, sanity_check last_action=54.084
# iteration: 130, avg dist 32.014,             median dist 15.445 sum of rewards=400.543,             buffer len = 6561, sanity_check last_action=31.897
# iteration: 131, avg dist 36.65,             median dist 18.212 sum of rewards=395.471,             buffer len = 6611, sanity_check last_action=20.261
# iteration: 132, avg dist 33.059,             median dist 15.273 sum of rewards=388.888,             buffer len = 6661, sanity_check last_action=28.08
# iteration: 133, avg dist 33.529,             median dist 15.261 sum of rewards=468.92,             buffer len = 6711, sanity_check last_action=8.742
# iteration: 134, avg dist 31.473,             median dist 15.331 sum of rewards=503.336,             buffer len = 6761, sanity_check last_action=34.311
# iteration: 135, avg dist 36.641,             median dist 15.139 sum of rewards=439.243,             buffer len = 6811, sanity_check last_action=26.049
# iteration: 136, avg dist 35.597,             median dist 15.002 sum of rewards=384.328,             buffer len = 6861, sanity_check last_action=31.462
# iteration: 137, avg dist 30.44,             median dist 13.532 sum of rewards=531.277,             buffer len = 6911, sanity_check last_action=36.3
# iteration: 138, avg dist 36.149,             median dist 16.147 sum of rewards=407.856,             buffer len = 6961, sanity_check last_action=44.547
# iteration: 139, avg dist 34.853,             median dist 13.888 sum of rewards=457.466,             buffer len = 7011, sanity_check last_action=21.361
# iteration: 140, avg dist 37.685,             median dist 16.074 sum of rewards=403.086,             buffer len = 7061, sanity_check last_action=28.214
# iteration: 141, avg dist 38.706,             median dist 15.523 sum of rewards=426.094,             buffer len = 7111, sanity_check last_action=18.186
# iteration: 142, avg dist 34.448,             median dist 15.877 sum of rewards=418.879,             buffer len = 7161, sanity_check last_action=34.938
# iteration: 143, avg dist 36.892,             median dist 15.484 sum of rewards=418.058,             buffer len = 7211, sanity_check last_action=18.716
# iteration: 144, avg dist 31.948,             median dist 13.746 sum of rewards=449.652,             buffer len = 7261, sanity_check last_action=20.116
# iteration: 145, avg dist 31.993,             median dist 14.017 sum of rewards=497.661,             buffer len = 7311, sanity_check last_action=35.261
# iteration: 146, avg dist 35.822,             median dist 15.299 sum of rewards=469.881,             buffer len = 7361, sanity_check last_action=33.259
# iteration: 147, avg dist 38.455,             median dist 17.259 sum of rewards=429.842,             buffer len = 7411, sanity_check last_action=27.845
# iteration: 148, avg dist 37.471,             median dist 16.434 sum of rewards=445.258,             buffer len = 7461, sanity_check last_action=39.392
# iteration: 149, avg dist 33.383,             median dist 13.503 sum of rewards=424.222,             buffer len = 7511, sanity_check last_action=14.613
# iteration: 150, avg dist 35.842,             median dist 16.032 sum of rewards=380.422,             buffer len = 7561, sanity_check last_action=37.485
# iteration: 151, avg dist 34.636,             median dist 16.099 sum of rewards=396.23,             buffer len = 7611, sanity_check last_action=49.446
# iteration: 152, avg dist 33.352,             median dist 14.655 sum of rewards=512.047,             buffer len = 7661, sanity_check last_action=10.107
# iteration: 153, avg dist 30.196,             median dist 14.997 sum of rewards=478.425,             buffer len = 7711, sanity_check last_action=53.951
# iteration: 154, avg dist 32.996,             median dist 15.037 sum of rewards=449.589,             buffer len = 7761, sanity_check last_action=53.834
# iteration: 155, avg dist 31.948,             median dist 13.428 sum of rewards=435.997,             buffer len = 7811, sanity_check last_action=43.91
# iteration: 156, avg dist 27.586,             median dist 12.412 sum of rewards=535.417,             buffer len = 7861, sanity_check last_action=15.59
# iteration: 157, avg dist 28.008,             median dist 12.885 sum of rewards=452.683,             buffer len = 7911, sanity_check last_action=27.34
# iteration: 158, avg dist 27.644,             median dist 15.568 sum of rewards=338.603,             buffer len = 7961, sanity_check last_action=51.622
# iteration: 159, avg dist 32.638,             median dist 14.949 sum of rewards=432.278,             buffer len = 8011, sanity_check last_action=18.802
# iteration: 160, avg dist 28.718,             median dist 13.801 sum of rewards=481.21,             buffer len = 8061, sanity_check last_action=23.613
# iteration: 161, avg dist 30.792,             median dist 13.437 sum of rewards=407.427,             buffer len = 8111, sanity_check last_action=18.276
# iteration: 162, avg dist 27.216,             median dist 12.328 sum of rewards=486.229,             buffer len = 8161, sanity_check last_action=35.095
# iteration: 163, avg dist 29.015,             median dist 13.033 sum of rewards=458.404,             buffer len = 8211, sanity_check last_action=6.39
# iteration: 164, avg dist 25.95,             median dist 11.292 sum of rewards=451.845,             buffer len = 8261, sanity_check last_action=15.481
# iteration: 165, avg dist 29.347,             median dist 12.681 sum of rewards=545.837,             buffer len = 8311, sanity_check last_action=13.164
# iteration: 166, avg dist 23.717,             median dist 11.332 sum of rewards=553.286,             buffer len = 8361, sanity_check last_action=45.147
# iteration: 167, avg dist 27.279,             median dist 12.013 sum of rewards=606.821,             buffer len = 8411, sanity_check last_action=53.435
# iteration: 168, avg dist 22.769,             median dist 10.052 sum of rewards=560.541,             buffer len = 8461, sanity_check last_action=35.314
# iteration: 169, avg dist 21.131,             median dist 10.82 sum of rewards=567.544,             buffer len = 8511, sanity_check last_action=36.688
# iteration: 170, avg dist 23.203,             median dist 11.585 sum of rewards=451.095,             buffer len = 8561, sanity_check last_action=33.641
# iteration: 171, avg dist 20.327,             median dist 9.673 sum of rewards=519.811,             buffer len = 8611, sanity_check last_action=15.091
# iteration: 172, avg dist 20.471,             median dist 10.121 sum of rewards=486.271,             buffer len = 8661, sanity_check last_action=18.513
# iteration: 173, avg dist 19.966,             median dist 10.383 sum of rewards=610.256,             buffer len = 8711, sanity_check last_action=19.085
# iteration: 174, avg dist 19.431,             median dist 10.268 sum of rewards=532.472,             buffer len = 8761, sanity_check last_action=25.195
# iteration: 175, avg dist 20.687,             median dist 10.232 sum of rewards=577.91,             buffer len = 8811, sanity_check last_action=13.179
# iteration: 176, avg dist 20.421,             median dist 12.314 sum of rewards=536.547,             buffer len = 8861, sanity_check last_action=39.416
# iteration: 177, avg dist 20.079,             median dist 10.163 sum of rewards=598.026,             buffer len = 8911, sanity_check last_action=47.508
# iteration: 178, avg dist 17.652,             median dist 9.796 sum of rewards=538.042,             buffer len = 8961, sanity_check last_action=46.125
# iteration: 179, avg dist 19.527,             median dist 10.639 sum of rewards=588.124,             buffer len = 9011, sanity_check last_action=25.36
# iteration: 180, avg dist 18.33,             median dist 9.312 sum of rewards=617.925,             buffer len = 9061, sanity_check last_action=35.398
# iteration: 181, avg dist 17.492,             median dist 8.894 sum of rewards=614.702,             buffer len = 9111, sanity_check last_action=8.526
# iteration: 182, avg dist 22.331,             median dist 12.631 sum of rewards=480.966,             buffer len = 9161, sanity_check last_action=1.463
# iteration: 183, avg dist 22.758,             median dist 11.42 sum of rewards=573.595,             buffer len = 9211, sanity_check last_action=39.847
# iteration: 184, avg dist 19.274,             median dist 10.635 sum of rewards=635.648,             buffer len = 9261, sanity_check last_action=15.01
# iteration: 185, avg dist 18.187,             median dist 10.746 sum of rewards=410.541,             buffer len = 9311, sanity_check last_action=34.462
# iteration: 186, avg dist 19.265,             median dist 9.77 sum of rewards=576.298,             buffer len = 9361, sanity_check last_action=20.87
# iteration: 187, avg dist 18.689,             median dist 10.476 sum of rewards=708.641,             buffer len = 9411, sanity_check last_action=39.349
# iteration: 188, avg dist 16.155,             median dist 8.511 sum of rewards=723.726,             buffer len = 9461, sanity_check last_action=32.372
# iteration: 189, avg dist 19.393,             median dist 11.147 sum of rewards=550.448,             buffer len = 9511, sanity_check last_action=14.601
# iteration: 190, avg dist 19.293,             median dist 11.253 sum of rewards=429.069,             buffer len = 9561, sanity_check last_action=12.412
# iteration: 191, avg dist 17.231,             median dist 10.144 sum of rewards=565.249,             buffer len = 9611, sanity_check last_action=18.962
# iteration: 192, avg dist 19.242,             median dist 10.225 sum of rewards=588.13,             buffer len = 9661, sanity_check last_action=27.416
# iteration: 193, avg dist 17.287,             median dist 7.995 sum of rewards=540.228,             buffer len = 9711, sanity_check last_action=42.358
# iteration: 194, avg dist 16.578,             median dist 8.102 sum of rewards=617.028,             buffer len = 9761, sanity_check last_action=36.23
# iteration: 195, avg dist 16.943,             median dist 9.452 sum of rewards=587.487,             buffer len = 9811, sanity_check last_action=25.79
# iteration: 196, avg dist 16.036,             median dist 9.12 sum of rewards=640.972,             buffer len = 9861, sanity_check last_action=34.727
# iteration: 197, avg dist 16.025,             median dist 9.527 sum of rewards=637.01,             buffer len = 9911, sanity_check last_action=36.23
# iteration: 198, avg dist 19.878,             median dist 10.872 sum of rewards=511.941,             buffer len = 9961, sanity_check last_action=5.868
# iteration: 199, avg dist 19.841,             median dist 10.295 sum of rewards=527.819,             buffer len = 10011, sanity_check last_action=39.82
# iteration: 200, avg dist 18.179,             median dist 10.493 sum of rewards=487.49,             buffer len = 10061, sanity_check last_action=9.825
# iteration: 201, avg dist 15.837,             median dist 8.275 sum of rewards=692.774,             buffer len = 10111, sanity_check last_action=7.313
# iteration: 202, avg dist 17.705,             median dist 9.155 sum of rewards=549.549,             buffer len = 10161, sanity_check last_action=27.17
# iteration: 203, avg dist 15.342,             median dist 8.743 sum of rewards=639.073,             buffer len = 10211, sanity_check last_action=27.662
# iteration: 204, avg dist 17.96,             median dist 8.857 sum of rewards=599.569,             buffer len = 10261, sanity_check last_action=40.874
# iteration: 205, avg dist 16.136,             median dist 9.11 sum of rewards=611.917,             buffer len = 10311, sanity_check last_action=15.976
# iteration: 206, avg dist 17.743,             median dist 8.606 sum of rewards=548.337,             buffer len = 10361, sanity_check last_action=30.426
# iteration: 207, avg dist 19.342,             median dist 10.115 sum of rewards=505.255,             buffer len = 10411, sanity_check last_action=7.679
# iteration: 208, avg dist 15.234,             median dist 8.541 sum of rewards=609.095,             buffer len = 10461, sanity_check last_action=11.241
# iteration: 209, avg dist 15.693,             median dist 8.181 sum of rewards=573.545,             buffer len = 10511, sanity_check last_action=7.722
# iteration: 210, avg dist 16.03,             median dist 8.629 sum of rewards=557.894,             buffer len = 10561, sanity_check last_action=10.04
# iteration: 211, avg dist 15.335,             median dist 8.418 sum of rewards=676.414,             buffer len = 10611, sanity_check last_action=15.739
# iteration: 212, avg dist 16.34,             median dist 8.799 sum of rewards=646.899,             buffer len = 10661, sanity_check last_action=16.459
# iteration: 213, avg dist 17.068,             median dist 8.764 sum of rewards=523.163,             buffer len = 10711, sanity_check last_action=15.627
# iteration: 214, avg dist 18.685,             median dist 12.843 sum of rewards=433.949,             buffer len = 10761, sanity_check last_action=19.764
# iteration: 215, avg dist 33.573,             median dist 16.057 sum of rewards=340.152,             buffer len = 10811, sanity_check last_action=49.703
# iteration: 216, avg dist 147.21,             median dist 92.822 sum of rewards=139.708,             buffer len = 10861, sanity_check last_action=84.832
# iteration: 217, avg dist 141.419,             median dist 90.849 sum of rewards=186.282,             buffer len = 10911, sanity_check last_action=72.379
# iteration: 218, avg dist 117.585,             median dist 63.45 sum of rewards=218.893,             buffer len = 10961, sanity_check last_action=73.459
# iteration: 219, avg dist 120.673,             median dist 63.394 sum of rewards=313.007,             buffer len = 11011, sanity_check last_action=33.405
# iteration: 220, avg dist 133.783,             median dist 72.447 sum of rewards=286.218,             buffer len = 11061, sanity_check last_action=19.2
# iteration: 221, avg dist 109.912,             median dist 55.598 sum of rewards=377.424,             buffer len = 11111, sanity_check last_action=53.977
# iteration: 222, avg dist 125.022,             median dist 64.396 sum of rewards=435.642,             buffer len = 11161, sanity_check last_action=56.305
# iteration: 223, avg dist 128.052,             median dist 67.686 sum of rewards=350.639,             buffer len = 11211, sanity_check last_action=4.122
# iteration: 224, avg dist 138.982,             median dist 75.073 sum of rewards=325.455,             buffer len = 11261, sanity_check last_action=79.57
# iteration: 225, avg dist 126.597,             median dist 61.857 sum of rewards=383.79,             buffer len = 11311, sanity_check last_action=2.192
# iteration: 226, avg dist 137.233,             median dist 66.453 sum of rewards=327.081,             buffer len = 11361, sanity_check last_action=80.424
# iteration: 227, avg dist 131.005,             median dist 57.225 sum of rewards=365.879,             buffer len = 11411, sanity_check last_action=13.703
# iteration: 228, avg dist 131.905,             median dist 59.439 sum of rewards=398.923,             buffer len = 11461, sanity_check last_action=24.827
# iteration: 229, avg dist 138.596,             median dist 67.692 sum of rewards=386.968,             buffer len = 11511, sanity_check last_action=72.421
# iteration: 230, avg dist 140.385,             median dist 69.803 sum of rewards=307.62,             buffer len = 11561, sanity_check last_action=50.864
# iteration: 231, avg dist 137.547,             median dist 73.199 sum of rewards=476.012,             buffer len = 11611, sanity_check last_action=46.26
# iteration: 232, avg dist 130.006,             median dist 63.079 sum of rewards=300.871,             buffer len = 11661, sanity_check last_action=79.821
# iteration: 233, avg dist 123.737,             median dist 62.897 sum of rewards=329.94,             buffer len = 11711, sanity_check last_action=80.388
# iteration: 234, avg dist 112.86,             median dist 51.893 sum of rewards=438.926,             buffer len = 11761, sanity_check last_action=45.32
# iteration: 235, avg dist 112.184,             median dist 46.978 sum of rewards=452.528,             buffer len = 11811, sanity_check last_action=58.743
# iteration: 236, avg dist 103.74,             median dist 42.453 sum of rewards=432.06,             buffer len = 11861, sanity_check last_action=35.94
# iteration: 237, avg dist 83.142,             median dist 33.069 sum of rewards=463.705,             buffer len = 11911, sanity_check last_action=56.645
# iteration: 238, avg dist 51.454,             median dist 19.385 sum of rewards=371.16,             buffer len = 11961, sanity_check last_action=50.99
# iteration: 239, avg dist 45.545,             median dist 19.253 sum of rewards=372.606,             buffer len = 12011, sanity_check last_action=38.846
# iteration: 240, avg dist 47.367,             median dist 18.872 sum of rewards=371.042,             buffer len = 12061, sanity_check last_action=12.331
# iteration: 241, avg dist 33.405,             median dist 13.588 sum of rewards=454.422,             buffer len = 12111, sanity_check last_action=31.279
# iteration: 242, avg dist 31.56,             median dist 12.196 sum of rewards=564.336,             buffer len = 12161, sanity_check last_action=50.328
# iteration: 243, avg dist 28.901,             median dist 16.072 sum of rewards=372.051,             buffer len = 12211, sanity_check last_action=6.561
# iteration: 244, avg dist 29.443,             median dist 24.59 sum of rewards=293.976,             buffer len = 12261, sanity_check last_action=39.052
# iteration: 245, avg dist 31.846,             median dist 26.289 sum of rewards=275.352,             buffer len = 12311, sanity_check last_action=24.041
# iteration: 246, avg dist 32.082,             median dist 31.329 sum of rewards=105.013,             buffer len = 12361, sanity_check last_action=33.714
# iteration: 247, avg dist 22.185,             median dist 11.76 sum of rewards=368.208,             buffer len = 12411, sanity_check last_action=24.516
# iteration: 248, avg dist 27.191,             median dist 13.459 sum of rewards=482.277,             buffer len = 12461, sanity_check last_action=18.299
# iteration: 249, avg dist 28.075,             median dist 12.286 sum of rewards=486.099,             buffer len = 12511, sanity_check last_action=23.799
# iteration: 250, avg dist 46.838,             median dist 17.979 sum of rewards=288.689,             buffer len = 12561, sanity_check last_action=36.634
# iteration: 251, avg dist 33.098,             median dist 14.005 sum of rewards=445.193,             buffer len = 12611, sanity_check last_action=15.62
# iteration: 252, avg dist 77.816,             median dist 28.63 sum of rewards=233.518,             buffer len = 12661, sanity_check last_action=58.364
# iteration: 253, avg dist 105.332,             median dist 60.172 sum of rewards=236.728,             buffer len = 12711, sanity_check last_action=30.783
# iteration: 254, avg dist 69.023,             median dist 30.49 sum of rewards=294.427,             buffer len = 12761, sanity_check last_action=31.571
# iteration: 255, avg dist 22.856,             median dist 12.153 sum of rewards=371.664,             buffer len = 12811, sanity_check last_action=16.899
# iteration: 256, avg dist 40.708,             median dist 17.466 sum of rewards=410.383,             buffer len = 12861, sanity_check last_action=41.831
# iteration: 257, avg dist 21.983,             median dist 10.804 sum of rewards=555.543,             buffer len = 12911, sanity_check last_action=34.122
# iteration: 258, avg dist 22.393,             median dist 11.728 sum of rewards=490.824,             buffer len = 12961, sanity_check last_action=20.991
# iteration: 259, avg dist 23.222,             median dist 10.196 sum of rewards=469.826,             buffer len = 13011, sanity_check last_action=19.155
# iteration: 260, avg dist 23.728,             median dist 12.8 sum of rewards=437.513,             buffer len = 13061, sanity_check last_action=17.202
# iteration: 261, avg dist 27.825,             median dist 21.544 sum of rewards=290.053,             buffer len = 13111, sanity_check last_action=18.695
# iteration: 262, avg dist 54.717,             median dist 22.93 sum of rewards=370.267,             buffer len = 13161, sanity_check last_action=28.203
# iteration: 263, avg dist 19.246,             median dist 9.319 sum of rewards=593.738,             buffer len = 13211, sanity_check last_action=33.269
# iteration: 264, avg dist 18.959,             median dist 10.772 sum of rewards=434.499,             buffer len = 13261, sanity_check last_action=18.647
# iteration: 265, avg dist 21.647,             median dist 10.908 sum of rewards=527.921,             buffer len = 13311, sanity_check last_action=21.634
# iteration: 266, avg dist 26.591,             median dist 10.767 sum of rewards=451.899,             buffer len = 13361, sanity_check last_action=40.773
# iteration: 267, avg dist 18.064,             median dist 9.184 sum of rewards=480.957,             buffer len = 13411, sanity_check last_action=52.069
# iteration: 268, avg dist 114.509,             median dist 58.405 sum of rewards=222.218,             buffer len = 13461, sanity_check last_action=44.914
# iteration: 269, avg dist 58.998,             median dist 22.69 sum of rewards=426.003,             buffer len = 13511, sanity_check last_action=25.659
# iteration: 270, avg dist 17.206,             median dist 9.859 sum of rewards=520.574,             buffer len = 13561, sanity_check last_action=16.66
# iteration: 271, avg dist 23.667,             median dist 12.365 sum of rewards=514.844,             buffer len = 13611, sanity_check last_action=40.015
# iteration: 272, avg dist 21.213,             median dist 9.991 sum of rewards=509.283,             buffer len = 13661, sanity_check last_action=45.662
# iteration: 273, avg dist 19.301,             median dist 9.848 sum of rewards=638.9,             buffer len = 13711, sanity_check last_action=11.611
# iteration: 274, avg dist 17.519,             median dist 7.961 sum of rewards=622.674,             buffer len = 13761, sanity_check last_action=37.259
# iteration: 275, avg dist 18.996,             median dist 9.618 sum of rewards=605.2,             buffer len = 13811, sanity_check last_action=23.643
# iteration: 276, avg dist 36.167,             median dist 16.977 sum of rewards=354.783,             buffer len = 13861, sanity_check last_action=19.818
# iteration: 277, avg dist 19.66,             median dist 10.07 sum of rewards=620.083,             buffer len = 13911, sanity_check last_action=25.524
# iteration: 278, avg dist 20.47,             median dist 9.547 sum of rewards=485.769,             buffer len = 13961, sanity_check last_action=24.445
# iteration: 279, avg dist 19.323,             median dist 10.525 sum of rewards=454.165,             buffer len = 14011, sanity_check last_action=37.12
# iteration: 280, avg dist 22.074,             median dist 11.205 sum of rewards=614.035,             buffer len = 14061, sanity_check last_action=6.912
# iteration: 281, avg dist 17.123,             median dist 9.011 sum of rewards=648.66,             buffer len = 14111, sanity_check last_action=15.853
# iteration: 282, avg dist 17.664,             median dist 8.994 sum of rewards=663.736,             buffer len = 14161, sanity_check last_action=34.55
# iteration: 283, avg dist 17.728,             median dist 8.99 sum of rewards=623.728,             buffer len = 14211, sanity_check last_action=20.106
# iteration: 284, avg dist 16.038,             median dist 8.319 sum of rewards=700.377,             buffer len = 14261, sanity_check last_action=7.707
# iteration: 285, avg dist 18.842,             median dist 8.551 sum of rewards=488.011,             buffer len = 14311, sanity_check last_action=39.445
# iteration: 286, avg dist 17.882,             median dist 9.861 sum of rewards=506.549,             buffer len = 14361, sanity_check last_action=21.804
# iteration: 287, avg dist 20.846,             median dist 10.804 sum of rewards=533.128,             buffer len = 14411, sanity_check last_action=4.854
# iteration: 288, avg dist 20.63,             median dist 10.403 sum of rewards=524.96,             buffer len = 14461, sanity_check last_action=16.526
# iteration: 289, avg dist 19.177,             median dist 9.447 sum of rewards=736.396,             buffer len = 14511, sanity_check last_action=25.543
# iteration: 290, avg dist 18.792,             median dist 9.434 sum of rewards=720.737,             buffer len = 14561, sanity_check last_action=25.111
# iteration: 291, avg dist 17.76,             median dist 8.776 sum of rewards=620.77,             buffer len = 14611, sanity_check last_action=27.821
# iteration: 292, avg dist 19.518,             median dist 10.117 sum of rewards=608.981,             buffer len = 14661, sanity_check last_action=42.016
# iteration: 293, avg dist 18.594,             median dist 9.218 sum of rewards=481.101,             buffer len = 14711, sanity_check last_action=33.772
# iteration: 294, avg dist 18.517,             median dist 9.954 sum of rewards=605.675,             buffer len = 14761, sanity_check last_action=41.596
# iteration: 295, avg dist 18.648,             median dist 8.952 sum of rewards=773.059,             buffer len = 14811, sanity_check last_action=37.704
# iteration: 296, avg dist 18.214,             median dist 8.981 sum of rewards=644.175,             buffer len = 14861, sanity_check last_action=14.31
# iteration: 297, avg dist 19.45,             median dist 9.797 sum of rewards=661.741,             buffer len = 14911, sanity_check last_action=39.533
# iteration: 298, avg dist 22.015,             median dist 10.936 sum of rewards=587.036,             buffer len = 14961, sanity_check last_action=22.908
# iteration: 299, avg dist 17.516,             median dist 9.274 sum of rewards=602.792,             buffer len = 15011, sanity_check last_action=21.737
# iteration: 300, avg dist 18.671,             median dist 9.847 sum of rewards=705.894,             buffer len = 15061, sanity_check last_action=19.505
# iteration: 301, avg dist 18.795,             median dist 9.671 sum of rewards=647.361,             buffer len = 15111, sanity_check last_action=31.492
# iteration: 302, avg dist 18.532,             median dist 9.009 sum of rewards=681.95,             buffer len = 15161, sanity_check last_action=46.284
# iteration: 303, avg dist 17.369,             median dist 8.048 sum of rewards=726.415,             buffer len = 15211, sanity_check last_action=41.006
# iteration: 304, avg dist 19.045,             median dist 10.007 sum of rewards=756.557,             buffer len = 15261, sanity_check last_action=8.18
# iteration: 305, avg dist 23.962,             median dist 9.99 sum of rewards=573.859,             buffer len = 15311, sanity_check last_action=28.225
# iteration: 306, avg dist 20.626,             median dist 9.714 sum of rewards=605.674,             buffer len = 15361, sanity_check last_action=28.629
# iteration: 307, avg dist 17.623,             median dist 9.016 sum of rewards=608.071,             buffer len = 15411, sanity_check last_action=40.764
# iteration: 308, avg dist 17.501,             median dist 8.6 sum of rewards=680.112,             buffer len = 15461, sanity_check last_action=28.262
# iteration: 309, avg dist 18.733,             median dist 9.379 sum of rewards=612.455,             buffer len = 15511, sanity_check last_action=30.889
# iteration: 310, avg dist 17.314,             median dist 8.608 sum of rewards=631.186,             buffer len = 15561, sanity_check last_action=5.258
# iteration: 311, avg dist 20.71,             median dist 9.243 sum of rewards=544.967,             buffer len = 15611, sanity_check last_action=20.907
# iteration: 312, avg dist 18.65,             median dist 10.189 sum of rewards=632.023,             buffer len = 15661, sanity_check last_action=7.296
# iteration: 313, avg dist 17.221,             median dist 8.898 sum of rewards=627.033,             buffer len = 15711, sanity_check last_action=42.834
# iteration: 314, avg dist 17.453,             median dist 8.349 sum of rewards=699.982,             buffer len = 15761, sanity_check last_action=23.974
# iteration: 315, avg dist 17.753,             median dist 8.486 sum of rewards=713.417,             buffer len = 15811, sanity_check last_action=27.589
# iteration: 316, avg dist 17.087,             median dist 9.892 sum of rewards=471.567,             buffer len = 15861, sanity_check last_action=26.558
# iteration: 317, avg dist 18.897,             median dist 8.441 sum of rewards=560.037,             buffer len = 15911, sanity_check last_action=19.831
# iteration: 318, avg dist 25.402,             median dist 11.992 sum of rewards=528.606,             buffer len = 15961, sanity_check last_action=19.253
# ...
# iteration: 2896, avg dist 2.273,             median dist 0.422 sum of rewards=2816.127,             buffer len = 144861, sanity_check last_action=40.015
# iteration: 2897, avg dist 2.593,             median dist 0.449 sum of rewards=2758.176,             buffer len = 144911, sanity_check last_action=24.529
# iteration: 2898, avg dist 2.704,             median dist 0.444 sum of rewards=2672.454,             buffer len = 144961, sanity_check last_action=41.579
# iteration: 2899, avg dist 2.115,             median dist 0.397 sum of rewards=2814.225,             buffer len = 145011, sanity_check last_action=46.13
# iteration: 2900, avg dist 2.254,             median dist 0.416 sum of rewards=2763.007,             buffer len = 145061, sanity_check last_action=32.159
# iteration: 2901, avg dist 2.26,             median dist 0.422 sum of rewards=2697.149,             buffer len = 145111, sanity_check last_action=32.891
# iteration: 2902, avg dist 2.383,             median dist 0.467 sum of rewards=2655.419,             buffer len = 145161, sanity_check last_action=26.805
# iteration: 2903, avg dist 2.343,             median dist 0.405 sum of rewards=2818.92,             buffer len = 145211, sanity_check last_action=32.48
# iteration: 2904, avg dist 2.491,             median dist 0.471 sum of rewards=2722.422,             buffer len = 145261, sanity_check last_action=39.655
# iteration: 2905, avg dist 2.558,             median dist 0.429 sum of rewards=2665.731,             buffer len = 145311, sanity_check last_action=16.272
# iteration: 2906, avg dist 2.793,             median dist 0.431 sum of rewards=2704.522,             buffer len = 145361, sanity_check last_action=37.901
# iteration: 2907, avg dist 2.529,             median dist 0.394 sum of rewards=2809.738,             buffer len = 145411, sanity_check last_action=26.47
# iteration: 2908, avg dist 2.096,             median dist 0.438 sum of rewards=2823.626,             buffer len = 145461, sanity_check last_action=37.279
# iteration: 2909, avg dist 2.222,             median dist 0.425 sum of rewards=2680.029,             buffer len = 145511, sanity_check last_action=21.893
# iteration: 2910, avg dist 2.379,             median dist 0.41 sum of rewards=2791.088,             buffer len = 145561, sanity_check last_action=44.674
# iteration: 2911, avg dist 2.593,             median dist 0.442 sum of rewards=2736.687,             buffer len = 145611, sanity_check last_action=20.77
# iteration: 2912, avg dist 2.426,             median dist 0.445 sum of rewards=2721.081,             buffer len = 145661, sanity_check last_action=11.567
# iteration: 2913, avg dist 1.769,             median dist 0.401 sum of rewards=2862.053,             buffer len = 145711, sanity_check last_action=27.634
# iteration: 2914, avg dist 2.407,             median dist 0.402 sum of rewards=2792.947,             buffer len = 145761, sanity_check last_action=31.87
# iteration: 2915, avg dist 2.393,             median dist 0.432 sum of rewards=2831.949,             buffer len = 145811, sanity_check last_action=27.338
# iteration: 2916, avg dist 2.234,             median dist 0.383 sum of rewards=2885.674,             buffer len = 145861, sanity_check last_action=22.85
# iteration: 2917, avg dist 2.294,             median dist 0.422 sum of rewards=2751.045,             buffer len = 145911, sanity_check last_action=19.767
# iteration: 2918, avg dist 2.5,             median dist 0.464 sum of rewards=2682.79,             buffer len = 145961, sanity_check last_action=29.502
# iteration: 2919, avg dist 2.474,             median dist 0.411 sum of rewards=2732.272,             buffer len = 146011, sanity_check last_action=30.084
# iteration: 2920, avg dist 2.206,             median dist 0.423 sum of rewards=2840.547,             buffer len = 146061, sanity_check last_action=15.645
# iteration: 2921, avg dist 2.18,             median dist 0.405 sum of rewards=2766.122,             buffer len = 146111, sanity_check last_action=30.489
# iteration: 2922, avg dist 2.262,             median dist 0.448 sum of rewards=2762.997,             buffer len = 146161, sanity_check last_action=38.92
# iteration: 2923, avg dist 2.232,             median dist 0.442 sum of rewards=2782.818,             buffer len = 146211, sanity_check last_action=30.528
# iteration: 2924, avg dist 2.312,             median dist 0.387 sum of rewards=2817.768,             buffer len = 146261, sanity_check last_action=33.788
# iteration: 2925, avg dist 2.534,             median dist 0.446 sum of rewards=2737.132,             buffer len = 146311, sanity_check last_action=34.139
# iteration: 2926, avg dist 1.961,             median dist 0.403 sum of rewards=2768.833,             buffer len = 146361, sanity_check last_action=23.183
# iteration: 2927, avg dist 2.251,             median dist 0.398 sum of rewards=2845.262,             buffer len = 146411, sanity_check last_action=13.907
# iteration: 2928, avg dist 2.453,             median dist 0.408 sum of rewards=2784.914,             buffer len = 146461, sanity_check last_action=20.513
# iteration: 2929, avg dist 2.331,             median dist 0.389 sum of rewards=2777.869,             buffer len = 146511, sanity_check last_action=11.96
# iteration: 2930, avg dist 2.416,             median dist 0.414 sum of rewards=2783.872,             buffer len = 146561, sanity_check last_action=13.096
# iteration: 2931, avg dist 2.298,             median dist 0.447 sum of rewards=2740.334,             buffer len = 146611, sanity_check last_action=39.12
# iteration: 2932, avg dist 2.275,             median dist 0.403 sum of rewards=2818.653,             buffer len = 146661, sanity_check last_action=36.384
# iteration: 2933, avg dist 2.42,             median dist 0.443 sum of rewards=2744.449,             buffer len = 146711, sanity_check last_action=21.05
# iteration: 2934, avg dist 2.177,             median dist 0.406 sum of rewards=2758.225,             buffer len = 146761, sanity_check last_action=41.803
# iteration: 2935, avg dist 2.396,             median dist 0.451 sum of rewards=2780.116,             buffer len = 146811, sanity_check last_action=28.184
# iteration: 2936, avg dist 2.208,             median dist 0.416 sum of rewards=2787.428,             buffer len = 146861, sanity_check last_action=14.993
# iteration: 2937, avg dist 2.447,             median dist 0.415 sum of rewards=2767.825,             buffer len = 146911, sanity_check last_action=21.873
# iteration: 2938, avg dist 2.066,             median dist 0.451 sum of rewards=2718.669,             buffer len = 146961, sanity_check last_action=18.119
# iteration: 2939, avg dist 2.498,             median dist 0.446 sum of rewards=2705.587,             buffer len = 147011, sanity_check last_action=7.589
# iteration: 2940, avg dist 2.234,             median dist 0.426 sum of rewards=2778.697,             buffer len = 147061, sanity_check last_action=29.999
# iteration: 2941, avg dist 2.358,             median dist 0.419 sum of rewards=2785.895,             buffer len = 147111, sanity_check last_action=13.905
# iteration: 2942, avg dist 2.152,             median dist 0.422 sum of rewards=2830.994,             buffer len = 147161, sanity_check last_action=47.689
# iteration: 2943, avg dist 2.029,             median dist 0.436 sum of rewards=2774.577,             buffer len = 147211, sanity_check last_action=19.092
# iteration: 2944, avg dist 2.328,             median dist 0.434 sum of rewards=2797.651,             buffer len = 147261, sanity_check last_action=28.975
# iteration: 2945, avg dist 2.245,             median dist 0.409 sum of rewards=2786.326,             buffer len = 147311, sanity_check last_action=9.437
# iteration: 2946, avg dist 2.694,             median dist 0.444 sum of rewards=2716.006,             buffer len = 147361, sanity_check last_action=32.454
# iteration: 2947, avg dist 2.328,             median dist 0.435 sum of rewards=2780.551,             buffer len = 147411, sanity_check last_action=32.588
# iteration: 2948, avg dist 2.579,             median dist 0.414 sum of rewards=2778.02,             buffer len = 147461, sanity_check last_action=31.879
# iteration: 2949, avg dist 2.498,             median dist 0.415 sum of rewards=2725.92,             buffer len = 147511, sanity_check last_action=3.204
# iteration: 2950, avg dist 2.114,             median dist 0.395 sum of rewards=2865.097,             buffer len = 147561, sanity_check last_action=26.865
# iteration: 2951, avg dist 2.257,             median dist 0.435 sum of rewards=2765.0,             buffer len = 147611, sanity_check last_action=30.361
# iteration: 2952, avg dist 2.373,             median dist 0.397 sum of rewards=2781.886,             buffer len = 147661, sanity_check last_action=24.184
# iteration: 2953, avg dist 2.389,             median dist 0.453 sum of rewards=2702.518,             buffer len = 147711, sanity_check last_action=27.86
# iteration: 2954, avg dist 2.222,             median dist 0.422 sum of rewards=2802.541,             buffer len = 147761, sanity_check last_action=41.95
# iteration: 2955, avg dist 2.517,             median dist 0.457 sum of rewards=2687.344,             buffer len = 147811, sanity_check last_action=5.072
# iteration: 2956, avg dist 2.469,             median dist 0.432 sum of rewards=2710.371,             buffer len = 147861, sanity_check last_action=48.054
# iteration: 2957, avg dist 1.946,             median dist 0.408 sum of rewards=2865.398,             buffer len = 147911, sanity_check last_action=18.658
# iteration: 2958, avg dist 2.593,             median dist 0.424 sum of rewards=2714.909,             buffer len = 147961, sanity_check last_action=24.329
# iteration: 2959, avg dist 2.244,             median dist 0.415 sum of rewards=2766.017,             buffer len = 148011, sanity_check last_action=17.434
# iteration: 2960, avg dist 2.459,             median dist 0.399 sum of rewards=2783.536,             buffer len = 148061, sanity_check last_action=25.151
# iteration: 2961, avg dist 2.195,             median dist 0.417 sum of rewards=2810.899,             buffer len = 148111, sanity_check last_action=24.565
# iteration: 2962, avg dist 1.75,             median dist 0.415 sum of rewards=2805.632,             buffer len = 148161, sanity_check last_action=24.611
# iteration: 2963, avg dist 2.304,             median dist 0.41 sum of rewards=2751.97,             buffer len = 148211, sanity_check last_action=26.147
# iteration: 2964, avg dist 2.212,             median dist 0.424 sum of rewards=2755.533,             buffer len = 148261, sanity_check last_action=26.515
# iteration: 2965, avg dist 2.54,             median dist 0.454 sum of rewards=2653.191,             buffer len = 148311, sanity_check last_action=27.008
# iteration: 2966, avg dist 2.257,             median dist 0.432 sum of rewards=2780.634,             buffer len = 148361, sanity_check last_action=19.693
# iteration: 2967, avg dist 2.448,             median dist 0.443 sum of rewards=2713.096,             buffer len = 148411, sanity_check last_action=30.908
# iteration: 2968, avg dist 2.198,             median dist 0.401 sum of rewards=2723.124,             buffer len = 148461, sanity_check last_action=16.388
# iteration: 2969, avg dist 2.403,             median dist 0.405 sum of rewards=2717.555,             buffer len = 148511, sanity_check last_action=44.833
# iteration: 2970, avg dist 2.386,             median dist 0.426 sum of rewards=2736.851,             buffer len = 148561, sanity_check last_action=17.104
# iteration: 2971, avg dist 2.447,             median dist 0.415 sum of rewards=2738.209,             buffer len = 148611, sanity_check last_action=38.031
# iteration: 2972, avg dist 2.557,             median dist 0.431 sum of rewards=2717.725,             buffer len = 148661, sanity_check last_action=40.114
# iteration: 2973, avg dist 2.307,             median dist 0.445 sum of rewards=2715.651,             buffer len = 148711, sanity_check last_action=31.415
# iteration: 2974, avg dist 2.32,             median dist 0.424 sum of rewards=2765.169,             buffer len = 148761, sanity_check last_action=26.975
# iteration: 2975, avg dist 2.406,             median dist 0.441 sum of rewards=2736.1,             buffer len = 148811, sanity_check last_action=15.188
# iteration: 2976, avg dist 2.426,             median dist 0.429 sum of rewards=2806.043,             buffer len = 148861, sanity_check last_action=40.386
# iteration: 2977, avg dist 2.357,             median dist 0.44 sum of rewards=2804.971,             buffer len = 148911, sanity_check last_action=29.598
# iteration: 2978, avg dist 2.145,             median dist 0.416 sum of rewards=2724.173,             buffer len = 148961, sanity_check last_action=34.292
# iteration: 2979, avg dist 2.141,             median dist 0.391 sum of rewards=2828.092,             buffer len = 149011, sanity_check last_action=38.375
# iteration: 2980, avg dist 2.372,             median dist 0.428 sum of rewards=2707.835,             buffer len = 149061, sanity_check last_action=14.194
# iteration: 2981, avg dist 2.285,             median dist 0.409 sum of rewards=2809.225,             buffer len = 149111, sanity_check last_action=29.284
# iteration: 2982, avg dist 2.241,             median dist 0.461 sum of rewards=2750.03,             buffer len = 149161, sanity_check last_action=25.582
# iteration: 2983, avg dist 2.029,             median dist 0.42 sum of rewards=2815.597,             buffer len = 149211, sanity_check last_action=30.5
# iteration: 2984, avg dist 2.296,             median dist 0.418 sum of rewards=2794.854,             buffer len = 149261, sanity_check last_action=24.4
# iteration: 2985, avg dist 2.078,             median dist 0.423 sum of rewards=2845.073,             buffer len = 149311, sanity_check last_action=19.626
# iteration: 2986, avg dist 2.363,             median dist 0.444 sum of rewards=2745.982,             buffer len = 149361, sanity_check last_action=29.304
# iteration: 2987, avg dist 1.803,             median dist 0.411 sum of rewards=2914.504,             buffer len = 149411, sanity_check last_action=34.549
# iteration: 2988, avg dist 2.107,             median dist 0.438 sum of rewards=2718.72,             buffer len = 149461, sanity_check last_action=15.547
# iteration: 2989, avg dist 2.151,             median dist 0.399 sum of rewards=2815.806,             buffer len = 149511, sanity_check last_action=23.237
# iteration: 2990, avg dist 2.456,             median dist 0.42 sum of rewards=2778.976,             buffer len = 149561, sanity_check last_action=7.483
# iteration: 2991, avg dist 2.119,             median dist 0.44 sum of rewards=2805.782,             buffer len = 149611, sanity_check last_action=20.201
# iteration: 2992, avg dist 2.031,             median dist 0.407 sum of rewards=2824.717,             buffer len = 149661, sanity_check last_action=24.514
# iteration: 2993, avg dist 2.279,             median dist 0.4 sum of rewards=2779.789,             buffer len = 149711, sanity_check last_action=35.827
# iteration: 2994, avg dist 2.387,             median dist 0.448 sum of rewards=2719.374,             buffer len = 149761, sanity_check last_action=51.936
# iteration: 2995, avg dist 2.3,             median dist 0.424 sum of rewards=2777.031,             buffer len = 149811, sanity_check last_action=27.937
# iteration: 2996, avg dist 1.986,             median dist 0.393 sum of rewards=2841.987,             buffer len = 149861, sanity_check last_action=11.437
# iteration: 2997, avg dist 2.27,             median dist 0.421 sum of rewards=2793.301,             buffer len = 149911, sanity_check last_action=29.838
# iteration: 2998, avg dist 2.111,             median dist 0.424 sum of rewards=2791.255,             buffer len = 149961, sanity_check last_action=34.087
# iteration: 2999, avg dist 2.328,             median dist 0.452 sum of rewards=2741.848,             buffer len = 150011, sanity_check last_action=23.279

# %%
agent.get_action([1.1, 60])
# Out:
# 27.001234137086435

# %%
27 ** 2 * np.sin(2 * 1.1) / 9.8
# Out:
# 60.14223248821236

# %%
Искусственное увеличение примеров положительного опыта приводит к тому, что происходит переобучение политики агента
1. Плохо аппроксимировалась Q-функция , увеличил количество слоев.
2. Идея - обучать сначала много Q-функцию и потом один раз делать градиентный подъем по стратегии.
3. Заменить выход стратегии на релу, чтобы не получать на выходе заведомо неверные ответы нейросети.

Пойдем по порядку.

# %% [markdown]
# ### Итог:
# ### Q-функция хорошо выучила среду. В среднем обученная стратегия промахивается на +- 3 метра, однако медианное значение ниже и составляет всего 1.5 метра, что в целом приемлемо для данного этапа обучения.

# %% [markdown]
# ## Задача решена.
