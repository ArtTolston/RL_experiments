# %% [markdown]
# ### Решать задачу Крестики-Нолики будем с использованием одного из табличных алгоритмов SARSA.
# #### Создадим вспомогательный класс

# %%
from pettingzoo.classic import tictactoe_v3

import numpy as np
import json
import pickle

# %%
class QFunctionClass:
    def __init__(self):
        self.qdict = {}
        self.action_n = 9

    def __getitem__(self, k):
        k = str(k)
        if k in self.qdict:
            return self.qdict[k]
        else:
            self.qdict[k] = np.zeros(self.action_n)
            return self.qdict[k]

    def __setitem__(self, k, v):
        k = str(k)
        self.qdict[k] = v

# %%
class RandomAgent:
    def __init__(self):
        pass

    def get_action(self, obsevation):
        mask = observation["action_mask"]
        action = env.action_space('player_2').sample(mask)
        return action

# %% [markdown]
# #### Создаем агента работающего по алгоритму SARSA

# %%
class SARSAAgent:
    def __init__(self, action_dim=9, side="X", alpha=0.5, episode_n=1000):
        self.qfunction = QFunctionClass()
        self.action_dim = action_dim
        self.side = side
        self.prev_state = ''
        self.prev_action = -1
        self.prev_reward = -1
        self.state = ''
        self.action = -1
        self.reward = -1
        self.episode_n = episode_n
        self.episode = 0.0
        self.epsilon = 1.0
        self.alpha = alpha
        self.gamma = 0.99

    def get_epsilon_greedy_action(self, q_values, epsilon, action_n, mask):
        policy = np.ones(action_n) * epsilon / action_n
        max_action = np.argmax(q_values)
        policy[max_action] += 1 - epsilon
        masked_policy = policy * mask
        p = 1.0 - np.sum(masked_policy)
        masked_policy = masked_policy + p / (1 - p) * masked_policy
        return np.random.choice(np.arange(action_n), p=masked_policy)

    def fit(self, reward, done):
        self.prev_reward = self.reward
        self.reward = reward
        if done:
            self.qfunction[self.prev_state][self.prev_action] += self.alpha * (self.reward - self.qfunction[self.prev_state][self.prev_action])
        else:
            if self.prev_state != '':
                self.qfunction[self.prev_state][self.prev_action] +=\
                self.alpha * (self.reward + self.gamma * self.qfunction[self.state][self.action]\
                              - self.qfunction[self.prev_state][self.prev_action])
        self.episode += 1.0
        self.epsilon = max(1.0 - self.episode / self.episode_n, 1e-6)

    def get_action(self, obs):
        mask = observation["action_mask"]               
        obs = observation["observation"]
        flatten_obs = np.array(obs).reshape(-1)
        flatten_obs = [str(i) for i in flatten_obs]
        # закидываем в предыдущее значение
        self.prev_state = self.state
        self.state = ''.join(flatten_obs)
        self.prev_action = self.action
        self.action = self.get_epsilon_greedy_action(self.qfunction[self.state], self.epsilon, self.action_dim, mask)
        return self.action

    def clear_state(self):
        self.prev_state = ''
        self.prev_action = -1
        self.prev_reward = -1
        self.state = ''
        self.action = -1
        self.reward = -1

    def save_model_pickle(self, path='/home/artem/atari_games/sarsa.json'):
        with open(path, 'wb') as f:
            pickle.dump(self.qfunction.qdict, f)

    def load_model_pickle(self, path='/home/artem/atari_games/sarsa.json'):
        with open(path, 'rb') as f:
            self.qfunction.qdict = pickle.load(f)

# %% [markdown]
# #### Обучаем стратегию

# %%
def print_board(player, obs):
    if player == "player_1":
        obs = obs["observation"]
        x = obs[:,:,0]
        o = obs[:,:,1]
    else:
        obs = obs["observation"]
        x = obs[:,:,1]
        o = obs[:,:,0]

    print("-------")
    for i in range(3):
        print("|", end="")
        for j in range(3):
            if x[i][j] == 1:
                print("x|", end="")
            elif o[i][j] == 1:
                print("o|", end="")
            else:
                print(" |", end="")
        print("\n--------")

# %%
env = tictactoe_v3.env()

episode_n = 15000

agent1 = SARSAAgent(alpha=0.8, episode_n=episode_n)
agent2 = SARSAAgent(alpha=0.8, episode_n=episode_n)

Agents = {'player_1': agent1, 'player_2': agent2}

for i in range(episode_n):
    if i % 1000 == 0:
        print(f'##################\niteration: {i}\n###################')
    if i == episode_n // 2:
        # смена игроков. Теперь начинает агент 2
        Agents['player_1'] = agent2
        Agents['player_2'] = agent1
        
    Agents['player_1'].clear_state()
    Agents['player_2'].clear_state()
    env.reset(seed=42)
    for agent_id in env.agent_iter():
        agent = Agents[agent_id]
        
        observation, reward, termination, truncation, info = env.last()

        if i % 1000 == 0:
            print_board(agent_id, observation)
    
        if termination or truncation:
            action = None
            
        else:
            action = agent.get_action(observation)
            
        agent.fit(reward, termination or truncation)
        
        if i % 1000 == 0:
            print(f"agent_id: {agent_id}, reward: {reward}, qfunction[prev_state]: {agent.qfunction[agent.prev_state]}\n qfunction[state]: {agent.qfunction[agent.state]}")
            
        env.step(action)

env.close()
# Out:
# ##################
# iteration: 0
# ###################
# -------
# | | | |
# --------
# | | | |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# | | | |
# --------
# | | | |
# --------
# |x| | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# | | |o|
# --------
# | | | |
# --------
# |x| | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |x| |o|
# --------
# | | | |
# --------
# |x| | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |x| |o|
# --------
# | |o| |
# --------
# |x| | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |x|x|o|
# --------
# | |o| |
# --------
# |x| | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |x|x|o|
# --------
# | |o|o|
# --------
# |x| | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |x|x|o|
# --------
# | |o|o|
# --------
# |x| |x|
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |x|x|o|
# --------
# |o|o|o|
# --------
# |x| |x|
# --------
# agent_id: player_1, reward: -1, qfunction[prev_state]: [ 0.  -0.8  0.   0.   0.   0.   0.   0.   0. ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |x|x|o|
# --------
# |o|o|o|
# --------
# |x| |x|
# --------
# agent_id: player_2, reward: 1, qfunction[prev_state]: [0.  0.  0.  0.  0.  0.8 0.  0.  0. ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# ##################
# iteration: 1000
# ###################
# -------
# | | | |
# --------
# | | | |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-2.70000783e-02  2.77109205e-02  4.18555729e-05 -1.25706176e-01
#   4.17708634e-01 -5.02824700e-03  4.52562983e-02  1.50604523e-01
#   1.37709288e-01]
# -------
# | | | |
# --------
# | | | |
# --------
# | | |x|
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-2.51995330e-04 -6.66879692e-01 -3.15887746e-02 -3.20000000e-02
#  -3.32800000e-02 -2.63577790e-02 -1.16541850e-02 -1.28000000e-03
#   0.00000000e+00]
# -------
# | | | |
# --------
# | | | |
# --------
# |o| |x|
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-2.70000783e-02  2.77109205e-02  4.18555729e-05 -1.25706176e-01
#   4.17708634e-01 -5.02824700e-03  4.52562983e-02  1.50604523e-01
#   6.30518195e-01]
#  qfunction[state]: [0.76133376 0.         0.         0.         0.         0.
#  0.         0.         0.        ]
# -------
# |x| | |
# --------
# | | | |
# --------
# |o| |x|
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [-2.51995330e-04 -6.66879692e-01 -3.15887746e-02 -3.20000000e-02
#  -3.32800000e-02 -2.63577790e-02 -6.35930837e-01 -1.28000000e-03
#   0.00000000e+00]
#  qfunction[state]: [ 0.         0.         0.         0.        -0.8        0.
#   0.        -0.0333312  0.       ]
# -------
# |x| | |
# --------
# | |o| |
# --------
# |o| |x|
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0.81121075 0.         0.         0.         0.         0.
#  0.         0.         0.        ]
#  qfunction[state]: [0.    0.    0.    0.    0.    0.832 0.    0.    0.   ]
# -------
# |x| | |
# --------
# | |o|x|
# --------
# |o| |x|
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [ 0.         0.         0.         0.        -0.16       0.
#   0.        -0.0333312  0.       ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |x| | |
# --------
# |o|o|x|
# --------
# |o| |x|
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0.     0.     0.     0.     0.     0.1664 0.     0.     0.    ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |x|x| |
# --------
# |o|o|x|
# --------
# |o| |x|
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |x|x| |
# --------
# |o|o|x|
# --------
# |o|o|x|
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |x|x|x|
# --------
# |o|o|x|
# --------
# |o|o|x|
# --------
# agent_id: player_2, reward: -1, qfunction[prev_state]: [ 0.   0.   0.  -0.8  0.   0.   0.   0.   0. ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |x|x|x|
# --------
# |o|o|x|
# --------
# |o|o|x|
# --------
# agent_id: player_1, reward: 1, qfunction[prev_state]: [0.  0.8 0.  0.  0.  0.  0.  0.  0. ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# ##################
# iteration: 2000
# ###################
# -------
# | | | |
# --------
# | | | |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [ 0.1690007  -0.02354749 -0.39691317  0.00589499 -0.56918985 -0.49245738
#  -0.49462133 -0.07682712 -0.00306322]
# -------
# |x| | |
# --------
# | | | |
# --------
# | | | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [ 0.         -0.03797503 -0.78079932 -0.66528602 -0.11411087 -0.50698754
#  -0.12858202 -0.00634879 -0.02000104]
# -------
# |x| | |
# --------
# | | | |
# --------
# |o| | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [ 0.17702212 -0.02354749 -0.39691317  0.00589499 -0.56918985 -0.49245738
#  -0.49462133 -0.07682712 -0.00306322]
#  qfunction[state]: [ 0.         -0.69963776  0.         -0.67328    -0.658944    0.
#   0.         -0.79624151  0.18083583]
# -------
# |x| | |
# --------
# | | | |
# --------
# |o| |x|
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [ 0.         -0.03797503 -0.78079932 -0.66528602 -0.11411087 -0.50698754
#  -0.0257164  -0.00634879 -0.02000104]
#  qfunction[state]: [ 0.          0.          0.         -0.16       -0.62878515 -0.00101376
#   0.         -0.10676437  0.        ]
# -------
# |x| |o|
# --------
# | | | |
# --------
# |o| |x|
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [ 0.         -0.69963776  0.         -0.67328    -0.658944    0.
#   0.         -0.79624151  0.03616717]
#  qfunction[state]: [ 0.   0.   0.   0.   0.  -0.8  0.   0.   0. ]
# -------
# |x| |o|
# --------
# | |x| |
# --------
# |o| |x|
# --------
# agent_id: player_2, reward: -1, qfunction[prev_state]: [ 0.         -0.03797503 -0.78079932 -0.66528602 -0.11411087 -0.50698754
#  -0.80514328 -0.00634879 -0.02000104]
#  qfunction[state]: [ 0.          0.          0.         -0.16       -0.62878515 -0.00101376
#   0.         -0.10676437  0.        ]
# -------
# |x| |o|
# --------
# | |x| |
# --------
# |o| |x|
# --------
# agent_id: player_1, reward: 1, qfunction[prev_state]: [ 0.         -0.69963776  0.         -0.67328    -0.658944    0.
#   0.         -0.79624151  0.80723343]
#  qfunction[state]: [ 0.   0.   0.   0.   0.  -0.8  0.   0.   0. ]
# ##################
# iteration: 3000
# ###################
# -------
# | | | |
# --------
# | | | |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.37993346 -0.4792842  -0.5031794  -0.3941038   0.76529521 -0.56202726
#  -0.52045406 -0.50025805 -0.47099234]
# -------
# | | | |
# --------
# | |x| |
# --------
# | | | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.71291035 -0.62877102 -0.70133333 -0.66707587  0.         -0.31614207
#  -0.12027567 -0.83735343 -0.00481739]
# -------
# | | | |
# --------
# | |x| |
# --------
# | | |o|
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.37993346 -0.4792842  -0.5031794  -0.3941038   0.25592524 -0.56202726
#  -0.52045406 -0.50025805 -0.47099234]
#  qfunction[state]: [-0.312064   -0.8         0.12988157 -0.66688     0.          0.
#  -0.79990501  0.          0.        ]
# -------
# | | |x|
# --------
# | |x| |
# --------
# | | |o|
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [-0.71291035 -0.62877102 -0.70133333 -0.66707587  0.         -0.31614207
#  -0.12027567 -0.83735343  0.50084772]
#  qfunction[state]: [-0.5452288  -0.80020275  0.          0.          0.         -0.79232
#  -0.12672     0.6336      0.        ]
# -------
# | | |x|
# --------
# | |x| |
# --------
# | |o|o|
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.312064   -0.8         0.02597631 -0.66688     0.          0.
#  -0.79990501  0.          0.        ]
#  qfunction[state]: [-0.8  0.   0.   0.   0.   0.   0.   0.   0. ]
# -------
# | |x|x|
# --------
# | |x| |
# --------
# | |o|o|
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [-0.5452288  -0.80020275  0.          0.          0.         -0.79232
#  -0.12672     0.12672     0.        ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |o|x|x|
# --------
# | |x| |
# --------
# | |o|o|
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.8  0.   0.   0.   0.   0.   0.   0.   0. ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |o|x|x|
# --------
# | |x| |
# --------
# |x|o|o|
# --------
# agent_id: player_2, reward: -1, qfunction[prev_state]: [-0.5452288  -0.80020275  0.          0.          0.         -0.79232
#  -0.12672    -0.774656    0.        ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |o|x|x|
# --------
# | |x| |
# --------
# |x|o|o|
# --------
# agent_id: player_1, reward: 1, qfunction[prev_state]: [-0.8  0.8  0.   0.   0.   0.   0.   0.   0. ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# ##################
# iteration: 4000
# ###################
# -------
# | | | |
# --------
# | | | |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.62065081  0.80164619 -0.64979218 -0.61517357 -0.66653275 -0.63035778
#  -0.68578479 -0.71395703 -0.63115767]
# -------
# | |x| |
# --------
# | | | |
# --------
# | | | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.20489667  0.         -0.12120272 -0.72082072 -0.83312213 -0.75624533
#   0.27828284 -0.6931451  -0.42194477]
# -------
# | |x| |
# --------
# | | | |
# --------
# |o| | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.62065081 -0.41405907 -0.64979218 -0.61517357 -0.66653275 -0.63035778
#  -0.68578479 -0.71395703 -0.63115767]
#  qfunction[state]: [-0.34192202  0.         -0.69339765 -0.025344   -0.72908787 -0.72523776
#   0.         -0.6285312  -0.0064    ]
# -------
# | |x| |
# --------
# | | |x|
# --------
# |o| | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [-0.20489667  0.         -0.12120272 -0.72082072 -0.83312213 -0.75624533
#   0.68418777 -0.6931451  -0.42194477]
#  qfunction[state]: [-0.67328   0.        0.        0.7936    0.        0.        0.
#   0.774912  0.6336  ]
# -------
# | |x| |
# --------
# |o| |x|
# --------
# |o| | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.34192202  0.         -0.69339765 -0.025344   -0.72908787 -0.14504755
#   0.         -0.6285312  -0.0064    ]
#  qfunction[state]: [-0.67328  0.       0.       0.       0.       0.       0.       0.
#   0.     ]
# -------
# | |x| |
# --------
# |o| |x|
# --------
# |o|x| |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [-0.67328   0.        0.        0.15872   0.        0.        0.
#   0.774912  0.6336  ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |o|x| |
# --------
# |o| |x|
# --------
# |o|x| |
# --------
# agent_id: player_1, reward: -1, qfunction[prev_state]: [-0.34192202  0.         -0.69339765 -0.025344   -0.72908787 -0.82900951
#   0.         -0.6285312  -0.0064    ]
#  qfunction[state]: [-0.67328  0.       0.       0.       0.       0.       0.       0.
#   0.     ]
# -------
# |o|x| |
# --------
# |o| |x|
# --------
# |o|x| |
# --------
# agent_id: player_2, reward: 1, qfunction[prev_state]: [-0.67328   0.        0.        0.831744  0.        0.        0.
#   0.774912  0.6336  ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# ##################
# iteration: 5000
# ###################
# -------
# | | | |
# --------
# | | | |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.78565479 -0.79321895 -0.77017365 -0.7668833   0.75708291 -0.7742124
#  -0.782647   -0.80191418 -0.76993214]
# -------
# | | | |
# --------
# | |x| |
# --------
# | | | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.01703373 -0.15836686 -0.70133333 -0.16332391  0.         -0.81243266
#  -0.08740183 -0.83217867 -0.72878933]
# -------
# |o| | |
# --------
# | |x| |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.78565479 -0.79321895 -0.77017365 -0.7668833   0.24443247 -0.7742124
#  -0.782647   -0.80191418 -0.76993214]
#  qfunction[state]: [ 0.         -0.81195297 -0.37975977  0.1174443   0.         -0.59164617
#  -0.12012962 -0.62531575 -0.02112676]
# -------
# |o| | |
# --------
# |x|x| |
# --------
# | | | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [-0.00340675 -0.15836686 -0.70133333 -0.16332391  0.         -0.81243266
#  -0.08740183 -0.83217867 -0.72878933]
#  qfunction[state]: [ 0.         -0.16500414 -0.79701561  0.          0.          0.
#  -0.82028495 -0.64024969 -0.69597694]
# -------
# |o| | |
# --------
# |x|x|o|
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [ 0.         -0.81195297 -0.37975977  0.02348886  0.         -0.59164617
#  -0.12012962 -0.62531575 -0.02112676]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |o| | |
# --------
# |x|x|o|
# --------
# | | |x|
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [ 0.         -0.16500414 -0.79701561  0.          0.          0.
#  -0.82028495 -0.64024969 -0.69597694]
#  qfunction[state]: [ 0.  -0.8  0.   0.   0.   0.   0.   0.   0. ]
# -------
# |o| | |
# --------
# |x|x|o|
# --------
# | |o|x|
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0.         0.         0.         0.         0.         0.
#  0.         0.         0.00101376]
#  qfunction[state]: [0.      0.      0.      0.      0.      0.      0.00128 0.      0.     ]
# -------
# |o| | |
# --------
# |x|x|o|
# --------
# |x|o|x|
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [ 0.  -0.8  0.   0.   0.   0.   0.   0.   0. ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |o| |o|
# --------
# |x|x|o|
# --------
# |x|o|x|
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0.       0.       0.       0.       0.       0.       0.000256 0.
#  0.      ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |o|x|o|
# --------
# |x|x|o|
# --------
# |x|o|x|
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [ 0.  -0.8  0.   0.   0.   0.   0.   0.   0. ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |o|x|o|
# --------
# |x|x|o|
# --------
# |x|o|x|
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 0.00e+00 5.12e-05 0.00e+00
#  0.00e+00]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# ##################
# iteration: 6000
# ###################
# -------
# | | | |
# --------
# | | | |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.78565479 -0.79321895 -0.77017365 -0.7668833   0.66417747 -0.7742124
#  -0.782647   -0.80191418 -0.76993214]
# -------
# | | | |
# --------
# | |x| |
# --------
# | | | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.78224512 -0.08788254 -0.70133333 -0.72882322  0.         -0.82221575
#  -0.81444278 -0.61649307 -0.72878933]
# -------
# | | | |
# --------
# | |x| |
# --------
# | |o| |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.78565479 -0.79321895 -0.77017365 -0.7668833   0.78129998 -0.7742124
#  -0.782647   -0.80191418 -0.76993214]
#  qfunction[state]: [-0.8         0.81876829 -0.64078907 -0.64128     0.          0.
#  -0.62707711  0.         -0.46186455]
# -------
# | |x| |
# --------
# | |x| |
# --------
# | |o| |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [-0.78224512 -0.08788254 -0.70133333 -0.72882322  0.         -0.82221575
#  -0.81444278 -0.75689861 -0.72878933]
#  qfunction[state]: [-0.7666561   0.         -0.80767958 -0.70133326  0.         -0.8
#  -0.7936      0.         -0.48681683]
# -------
# | |x| |
# --------
# | |x|o|
# --------
# | |o| |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.8         0.79735366 -0.64078907 -0.64128     0.          0.
#  -0.62707711  0.         -0.46186455]
#  qfunction[state]: [0.8 0.  0.  0.  0.  0.  0.  0.  0. ]
# -------
# |x|x| |
# --------
# | |x|o|
# --------
# | |o| |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [-0.7666561   0.         -0.80767958 -0.70133326  0.         -0.16
#  -0.7936      0.         -0.48681683]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |x|x| |
# --------
# | |x|o|
# --------
# | |o|o|
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0.818944 0.       0.       0.       0.       0.       0.       0.
#  0.      ]
#  qfunction[state]: [0.    0.    0.    0.    0.    0.    0.832 0.    0.   ]
# -------
# |x|x| |
# --------
# | |x|o|
# --------
# |x|o|o|
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |x|x|o|
# --------
# | |x|o|
# --------
# |x|o|o|
# --------
# agent_id: player_1, reward: -1, qfunction[prev_state]: [-0.6362112  0.         0.         0.         0.         0.
#   0.         0.         0.       ]
#  qfunction[state]: [0.    0.    0.    0.    0.    0.    0.832 0.    0.   ]
# -------
# |x|x|o|
# --------
# | |x|o|
# --------
# |x|o|o|
# --------
# agent_id: player_2, reward: 1, qfunction[prev_state]: [0.  0.  0.  0.  0.  0.  0.  0.  0.8]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# ##################
# iteration: 7000
# ###################
# -------
# | | | |
# --------
# | | | |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.78565479 -0.79321895 -0.77017365 -0.7668833   0.59058872 -0.7742124
#  -0.782647   -0.80191418 -0.76993214]
# -------
# | | | |
# --------
# | |x| |
# --------
# | | | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.45439287 -0.82720543 -0.70133333 -0.72882322  0.         -0.81408391
#  -0.83333333 -0.06831165 -0.72878933]
# -------
# |o| | |
# --------
# | |x| |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.78565479 -0.79321895 -0.77017365 -0.7668833   0.22810886 -0.7742124
#  -0.782647   -0.80191418 -0.76993214]
#  qfunction[state]: [ 0.          0.13887768 -0.39184146 -0.68607537  0.         -0.51944956
#  -0.66294975 -0.81918446 -0.67463005]
# -------
# |o|x| |
# --------
# | |x| |
# --------
# | | | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [-0.61882347 -0.82720543 -0.70133333 -0.72882322  0.         -0.81408391
#  -0.83333333 -0.06831165 -0.72878933]
#  qfunction[state]: [ 0.          0.         -0.00769885 -0.69180919  0.         -0.75424435
#  -0.75987805 -0.81841497 -0.66659709]
# -------
# |o|x| |
# --------
# | |x| |
# --------
# | | |o|
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [ 0.          0.65487227 -0.39184146 -0.68607537  0.         -0.51944956
#  -0.66294975 -0.81918446 -0.67463005]
#  qfunction[state]: [ 0.         0.         0.         0.         0.        -0.7670001
#   0.7917888  0.         0.       ]
# -------
# |o|x| |
# --------
# | |x| |
# --------
# |x| |o|
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [ 0.          0.         -0.00769885 -0.69180919  0.         -0.75424435
#  -0.75987805 -0.81841497  0.52461082]
#  qfunction[state]: [ 0.          0.         -0.83333325 -0.832       0.          0.83072
#   0.         -0.832       0.        ]
# -------
# |o|x| |
# --------
# | |x|o|
# --------
# |x| |o|
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [ 0.          0.          0.          0.          0.         -0.7670001
#   0.81835607  0.          0.        ]
#  qfunction[state]: [0.        0.        0.        0.8333312 0.        0.        0.
#  0.        0.       ]
# -------
# |o|x| |
# --------
# |x|x|o|
# --------
# |x| |o|
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [ 0.          0.         -0.83333325 -0.832       0.          0.166144
#   0.         -0.832       0.        ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |o|x|o|
# --------
# |x|x|o|
# --------
# |x| |o|
# --------
# agent_id: player_1, reward: -1, qfunction[prev_state]: [ 0.          0.          0.          0.          0.         -0.7670001
#  -0.63632879  0.          0.        ]
#  qfunction[state]: [0.        0.        0.        0.8333312 0.        0.        0.
#  0.        0.       ]
# -------
# |o|x|o|
# --------
# |x|x|o|
# --------
# |x| |o|
# --------
# agent_id: player_2, reward: 1, qfunction[prev_state]: [ 0.          0.         -0.83333325 -0.832       0.          0.8332288
#   0.         -0.832       0.        ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# ##################
# iteration: 8000
# ###################
# -------
# | | | |
# --------
# | | | |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.6336     -0.6336     -0.63665942 -0.6336     -0.40638054 -0.53040024
#  -0.54440317 -0.5018112  -0.52625211]
# -------
# | | | |
# --------
# | |x| |
# --------
# | | | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [ 0.6031872 -0.832     -0.6336    -0.0065921  0.         0.
#   0.        -0.6336     0.       ]
# -------
# |o| | |
# --------
# | |x| |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.6336     -0.6336     -0.63665942 -0.6336      0.31388754 -0.53040024
#  -0.54440317 -0.5018112  -0.52625211]
#  qfunction[state]: [0.       0.       0.       0.       0.       0.       0.       0.498944
#  0.      ]
# -------
# |o| | |
# --------
# | |x| |
# --------
# | |x| |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [-0.53830656 -0.832      -0.6336     -0.0065921   0.          0.
#   0.         -0.6336      0.        ]
#  qfunction[state]: [ 0.       0.      -0.76928  0.       0.       0.      -0.832    0.
#   0.     ]
# -------
# |o| | |
# --------
# | |x| |
# --------
# |o|x| |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0.        0.        0.        0.        0.        0.        0.
#  0.7587328 0.       ]
#  qfunction[state]: [0.    0.    0.    0.832 0.    0.    0.    0.    0.   ]
# -------
# |o| | |
# --------
# |x|x| |
# --------
# |o|x| |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [ 0.       0.      -0.76928  0.       0.       0.      -0.1664   0.
#   0.     ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |o|o| |
# --------
# |x|x| |
# --------
# |o|x| |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0.     0.     0.     0.1664 0.     0.     0.     0.     0.    ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |o|o| |
# --------
# |x|x|x|
# --------
# |o|x| |
# --------
# agent_id: player_2, reward: -1, qfunction[prev_state]: [ 0.       0.      -0.76928  0.       0.       0.      -0.83328  0.
#   0.     ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |o|o| |
# --------
# |x|x|x|
# --------
# |o|x| |
# --------
# agent_id: player_1, reward: 1, qfunction[prev_state]: [0.      0.      0.      0.83328 0.      0.      0.      0.      0.     ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# ##################
# iteration: 9000
# ###################
# -------
# | | | |
# --------
# | | | |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.785664   -0.63375182 -0.63665942 -0.68027351 -0.71191297 -0.63380235
#  -0.6571979  -0.02007243 -0.65753599]
# -------
# | | | |
# --------
# | | | |
# --------
# | |x| |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [ 0.0228838  -0.5018112  -0.13224296 -0.6336     -0.15513307 -0.66121482
#  -0.25344     0.          0.        ]
# -------
# |o| | |
# --------
# | | | |
# --------
# | |x| |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.785664   -0.63375182 -0.63665942 -0.68027351 -0.71191297 -0.63380235
#  -0.6571979   0.51863994 -0.65753599]
#  qfunction[state]: [ 0.          0.65991721  0.          0.         -0.0050688  -0.12672
#   0.          0.          0.        ]
# -------
# |o|x| |
# --------
# | | | |
# --------
# | |x| |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [ 0.00457676 -0.5018112  -0.13224296 -0.6336     -0.15513307 -0.66121482
#  -0.25344     0.          0.        ]
#  qfunction[state]: [ 0.       0.      -0.67328  0.       0.       0.       0.       0.
#   0.     ]
# -------
# |o|x| |
# --------
# | |o| |
# --------
# | |x| |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [ 0.          0.13198344  0.          0.         -0.0050688  -0.12672
#   0.          0.          0.        ]
#  qfunction[state]: [ 0.     0.    -0.832  0.     0.     0.     0.     0.     0.   ]
# -------
# |o|x| |
# --------
# |x|o| |
# --------
# | |x| |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [ 0.       0.      -0.67328  0.       0.       0.       0.       0.
#   0.     ]
#  qfunction[state]: [ 0.     0.    -0.768  0.     0.     0.     0.     0.     0.   ]
# -------
# |o|x| |
# --------
# |x|o|o|
# --------
# | |x| |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [ 0.      0.     -0.832   0.6336  0.      0.      0.      0.      0.    ]
#  qfunction[state]: [0.  0.  0.  0.  0.  0.  0.  0.  0.8]
# -------
# |o|x| |
# --------
# |x|o|o|
# --------
# | |x|x|
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [ 0.     0.    -0.768  0.     0.     0.     0.     0.     0.   ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |o|x|o|
# --------
# |x|o|o|
# --------
# | |x|x|
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0.   0.   0.   0.   0.   0.   0.   0.   0.16]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |o|x|o|
# --------
# |x|o|o|
# --------
# |x|x|x|
# --------
# agent_id: player_2, reward: -1, qfunction[prev_state]: [ 0.     0.    -0.768  0.     0.    -0.8    0.     0.     0.   ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |o|x|o|
# --------
# |x|o|o|
# --------
# |x|x|x|
# --------
# agent_id: player_1, reward: 1, qfunction[prev_state]: [0.    0.    0.    0.    0.    0.    0.    0.    0.832]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# ##################
# iteration: 10000
# ###################
# -------
# | | | |
# --------
# | | | |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.785664   -0.76880701 -0.73202685 -0.71888342 -0.71191297 -0.7445287
#   0.82067131 -0.74352899 -0.73842994]
# -------
# | | | |
# --------
# | | | |
# --------
# |x| | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.74866669 -0.76597942 -0.83333333 -0.02890433 -0.83333333 -0.83333333
#   0.         -0.01236231 -0.83333333]
# -------
# | | | |
# --------
# | | | |
# --------
# |x|o| |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.785664   -0.76880701 -0.73202685 -0.71888342 -0.71191297 -0.7445287
#   0.20914191 -0.74352899 -0.73842994]
#  qfunction[state]: [-0.6336      0.05682783  0.          0.          0.          0.
#   0.          0.          0.        ]
# -------
# | |x| |
# --------
# | | | |
# --------
# |x|o| |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [-0.74866669 -0.76597942 -0.83333333 -0.02890433 -0.83333333 -0.83333333
#   0.         -0.0066897  -0.83333333]
#  qfunction[state]: [-0.00780555  0.         -0.00129024 -0.83328    -0.00101376 -0.0053248
#   0.          0.          0.        ]
# -------
# | |x| |
# --------
# | | |o|
# --------
# |x|o| |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.6336      0.01136557  0.          0.          0.          0.
#   0.          0.          0.        ]
#  qfunction[state]: [-0.66666701  0.          0.          0.          0.          0.
#   0.          0.         -0.79472845]
# -------
# | |x|x|
# --------
# | | |o|
# --------
# |x|o| |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [-0.00780555  0.         -0.00129024 -0.83328    -0.00101376 -0.00106496
#   0.          0.          0.        ]
#  qfunction[state]: [-0.8  0.   0.   0.   0.   0.   0.   0.   0. ]
# -------
# | |x|x|
# --------
# | |o|o|
# --------
# |x|o| |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.66666701  0.          0.          0.          0.          0.
#   0.          0.         -0.79472845]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |x|x|x|
# --------
# | |o|o|
# --------
# |x|o| |
# --------
# agent_id: player_2, reward: -1, qfunction[prev_state]: [-0.00780555  0.         -0.00129024 -0.83328    -0.00101376 -0.80021299
#   0.          0.          0.        ]
#  qfunction[state]: [-0.8  0.   0.   0.   0.   0.   0.   0.   0. ]
# -------
# |x|x|x|
# --------
# | |o|o|
# --------
# |x|o| |
# --------
# agent_id: player_1, reward: 1, qfunction[prev_state]: [-0.66666701  0.          0.8         0.          0.          0.
#   0.          0.         -0.79472845]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# ##################
# iteration: 11000
# ###################
# -------
# | | | |
# --------
# | | | |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.785664   -0.76880701 -0.73202685 -0.71888342 -0.71191297 -0.7445287
#   0.37597908 -0.74352899 -0.73842994]
# -------
# | | | |
# --------
# | | | |
# --------
# |x| | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.0065904  -0.80460915 -0.83333333 -0.02551249 -0.83333333 -0.83333333
#   0.          0.13528766 -0.83333333]
# -------
# | | | |
# --------
# | | | |
# --------
# |x|o| |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.785664   -0.76880701 -0.73202685 -0.71888342 -0.71191297 -0.7445287
#   0.55371248 -0.74352899 -0.73842994]
#  qfunction[state]: [-0.6336     -0.36764137 -0.74720338 -0.12161065  0.60418771  0.
#   0.          0.          0.        ]
# -------
# | | | |
# --------
# | |x| |
# --------
# |x|o| |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [-0.0065904  -0.80460915 -0.83333333 -0.02551249 -0.83333333 -0.83333333
#   0.          0.04286408 -0.83333333]
#  qfunction[state]: [-0.00730102 -0.66693333 -0.032      -0.76640256  0.          0.01995776
#   0.          0.         -0.10191751]
# -------
# | | | |
# --------
# | |x|o|
# --------
# |x|o| |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.6336     -0.36764137 -0.74720338 -0.12161065  0.12083754  0.
#   0.          0.          0.        ]
#  qfunction[state]: [-0.64560169  0.          0.          0.          0.          0.
#   0.          0.          0.        ]
# -------
# | |x| |
# --------
# | |x|o|
# --------
# |x|o| |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [-0.00730102 -0.66693333 -0.032      -0.76640256  0.          0.00399155
#   0.          0.         -0.10191751]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |o|x| |
# --------
# | |x|o|
# --------
# |x|o| |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.64560169  0.00105438  0.          0.          0.          0.
#   0.          0.          0.        ]
#  qfunction[state]: [0.         0.         0.         0.         0.         0.
#  0.         0.         0.00133128]
# -------
# |o|x| |
# --------
# | |x|o|
# --------
# |x|o|x|
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |o|x| |
# --------
# |o|x|o|
# --------
# |x|o|x|
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0.         0.         0.         0.         0.         0.
#  0.         0.         0.00026626]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |o|x|x|
# --------
# |o|x|o|
# --------
# |x|o|x|
# --------
# agent_id: player_2, reward: -1, qfunction[prev_state]: [-0.8  0.   0.   0.   0.   0.   0.   0.   0. ]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |o|x|x|
# --------
# |o|x|o|
# --------
# |x|o|x|
# --------
# agent_id: player_1, reward: 1, qfunction[prev_state]: [0.         0.         0.         0.         0.         0.
#  0.         0.         0.80005325]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# ##################
# iteration: 12000
# ###################
# -------
# | | | |
# --------
# | | | |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.785664   -0.76880701  0.28863335 -0.77683162 -0.7540912  -0.7445287
#  -0.7422218  -0.74352899 -0.73842994]
# -------
# | | |x|
# --------
# | | | |
# --------
# | | | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.14408574 -0.12647247  0.         -0.83333333 -0.76861408 -0.8333329
#  -0.19507756 -0.82627635 -0.83333333]
# -------
# | | |x|
# --------
# | |o| |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.785664   -0.76880701 -0.57440541 -0.77683162 -0.7540912  -0.7445287
#  -0.7422218  -0.74352899 -0.73842994]
#  qfunction[state]: [-0.76932907 -0.75640832  0.          0.          0.         -0.47533868
#  -0.6949377  -0.79814656 -0.64688829]
# -------
# | | |x|
# --------
# | |o| |
# --------
# | |x| |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [-0.14408574 -0.12647247  0.         -0.83333333  0.47877863 -0.8333329
#  -0.19507756 -0.82627635 -0.83333333]
#  qfunction[state]: [0.79861294 0.         0.         0.         0.         0.
#  0.         0.         0.        ]
# -------
# |o| |x|
# --------
# | |o| |
# --------
# | |x| |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.76932907 -0.75640832  0.          0.          0.         -0.47533868
#  -0.6949377  -0.15962931 -0.64688829]
#  qfunction[state]: [ 0.        -0.8333312  0.        -0.8064     0.         0.
#   0.         0.         0.       ]
# -------
# |o| |x|
# --------
# | |o| |
# --------
# |x|x| |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0.15972259 0.         0.         0.         0.         0.
#  0.         0.         0.        ]
#  qfunction[state]: [ 0.    -0.768  0.    -0.8    0.    -0.8    0.     0.     0.   ]
# -------
# |o| |x|
# --------
# | |o| |
# --------
# |x|x|o|
# --------
# agent_id: player_1, reward: -1, qfunction[prev_state]: [-0.76932907 -0.75640832  0.          0.          0.         -0.47533868
#  -0.6949377  -0.83192586 -0.64688829]
#  qfunction[state]: [ 0.        -0.8333312  0.        -0.8064     0.         0.
#   0.         0.         0.       ]
# -------
# |o| |x|
# --------
# | |o| |
# --------
# |x|x|o|
# --------
# agent_id: player_2, reward: 1, qfunction[prev_state]: [0.83194452 0.         0.         0.         0.         0.
#  0.         0.         0.        ]
#  qfunction[state]: [ 0.    -0.768  0.    -0.8    0.    -0.8    0.     0.     0.   ]
# ##################
# iteration: 13000
# ###################
# -------
# | | | |
# --------
# | | | |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.785664   -0.76880701 -0.79632066 -0.77683162  0.80941239 -0.79841442
#  -0.80892894 -0.76561195 -0.7795546 ]
# -------
# | | | |
# --------
# | |x| |
# --------
# | | | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.55620284 -0.00131169 -0.83333333 -0.80118641  0.         -0.71739077
#  -0.83326559 -0.82847311 -0.6644447 ]
# -------
# | | |o|
# --------
# | |x| |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.785664   -0.76880701 -0.79632066 -0.77683162  0.82188248 -0.79841442
#  -0.80892894 -0.76561195 -0.7795546 ]
#  qfunction[state]: [-0.67328    -0.01492951  0.         -0.608256    0.          0.
#   0.          0.          0.83333333]
# -------
# | | |o|
# --------
# | |x| |
# --------
# | | |x|
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [-0.55620284 -0.00131169 -0.16666667 -0.80118641  0.         -0.71739077
#  -0.83326559 -0.82847311 -0.6644447 ]
#  qfunction[state]: [-0.768  0.     0.     0.     0.     0.     0.     0.     0.   ]
# -------
# | |o|o|
# --------
# | |x| |
# --------
# | | |x|
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.67328    -0.01492951  0.         -0.608256    0.          0.
#   0.          0.          0.16666667]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |x|o|o|
# --------
# | |x| |
# --------
# | | |x|
# --------
# agent_id: player_2, reward: -1, qfunction[prev_state]: [-0.55620284 -0.00131169 -0.83333333 -0.80118641  0.         -0.71739077
#  -0.83326559 -0.82847311 -0.6644447 ]
#  qfunction[state]: [-0.768  0.     0.     0.     0.     0.     0.     0.     0.   ]
# -------
# |x|o|o|
# --------
# | |x| |
# --------
# | | |x|
# --------
# agent_id: player_1, reward: 1, qfunction[prev_state]: [-0.67328    -0.01492951  0.         -0.608256    0.          0.
#   0.          0.          0.83333333]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# ##################
# iteration: 14000
# ###################
# -------
# | | | |
# --------
# | | | |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.785664   -0.77271001 -0.79632066 -0.77683162  0.20664099 -0.79841442
#  -0.80892894 -0.81176098 -0.7795546 ]
# -------
# | | | |
# --------
# | |x| |
# --------
# | | | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  qfunction[state]: [-0.7592016  -0.25312527 -0.83333333 -0.83333333  0.         -0.04211555
#  -0.83333333 -0.83333333 -0.51860006]
# -------
# | |o| |
# --------
# | |x| |
# --------
# | | | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.785664   -0.77271001 -0.79632066 -0.77683162  0.56867984 -0.79841442
#  -0.80892894 -0.81176098 -0.7795546 ]
#  qfunction[state]: [-0.48422588  0.         -0.48026113 -0.47067285  0.         -0.032
#   0.66584803 -0.66528229 -0.72230328]
# -------
# | |o| |
# --------
# | |x| |
# --------
# |x| | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [-0.7592016  -0.66248843 -0.83333333 -0.83333333  0.         -0.04211555
#  -0.83333333 -0.83333333 -0.51860006]
#  qfunction[state]: [-0.70357902  0.         -0.16128    -0.66510766  0.         -0.77255476
#   0.         -0.82499174 -0.82114365]
# -------
# | |o| |
# --------
# | |x|o|
# --------
# |x| | |
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [-0.48422588  0.         -0.48026113 -0.47067285  0.         -0.032
#   0.7868251  -0.66528229 -0.72230328]
#  qfunction[state]: [0.82532259 0.         0.         0.         0.         0.
#  0.         0.         0.        ]
# -------
# |x|o| |
# --------
# | |x|o|
# --------
# |x| | |
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [-0.70357902  0.         -0.16128    -0.66510766  0.          0.45277346
#   0.         -0.82499174 -0.82114365]
#  qfunction[state]: [ 0.          0.          0.         -0.8333312   0.          0.
#   0.          0.          0.76677325]
# -------
# |x|o| |
# --------
# | |x|o|
# --------
# |x| |o|
# --------
# agent_id: player_1, reward: 0, qfunction[prev_state]: [0.82506452 0.         0.         0.         0.         0.
#  0.         0.         0.        ]
#  qfunction[state]: [0.         0.         0.         0.         0.         0.
#  0.         0.83333333 0.        ]
# -------
# |x|o| |
# --------
# | |x|o|
# --------
# |x|x|o|
# --------
# agent_id: player_2, reward: 0, qfunction[prev_state]: [ 0.          0.          0.         -0.8333312   0.          0.
#   0.          0.          0.15335465]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]
# -------
# |x|o|o|
# --------
# | |x|o|
# --------
# |x|x|o|
# --------
# agent_id: player_1, reward: -1, qfunction[prev_state]: [-0.6349871  0.         0.         0.         0.         0.
#   0.         0.         0.       ]
#  qfunction[state]: [0.         0.         0.         0.         0.         0.
#  0.         0.83333333 0.        ]
# -------
# |x|o|o|
# --------
# | |x|o|
# --------
# |x|x|o|
# --------
# agent_id: player_2, reward: 1, qfunction[prev_state]: [ 0.          0.          0.         -0.8333312   0.          0.
#   0.          0.          0.83067093]
#  qfunction[state]: [0. 0. 0. 0. 0. 0. 0. 0. 0.]

# %% [markdown]
# #### Сохраняем модель

# %%
# agent1.save_model_pickle('one-side_tic')
# agent2.save_model_pickle('one-side_tac')
agent1.save_model_pickle()

# %% [markdown]
# #### Проверяем в игре против рандомной стратегии

# %%
from pettingzoo.classic import tictactoe_v3

env = tictactoe_v3.env()
env.reset(seed=45)

agent1 = SARSAAgent()
agent1.load_model_pickle()
agent1.epsilon = 0.000001

agent2 = RandomAgent()

# agent2 = SARSAAgent()
# agent2.load_model_pickle('one-side_tac')
# agent2.epsilon = 0.0001

Agents = {'player_1': agent1, 'player_2': agent2}
games_n = 1000
wins = 0
losses = 0
for i in range(games_n):
    j = 0
    env.reset()
    for agent_id in env.agent_iter():
        agent = Agents[agent_id]
        observation, reward, termination, truncation, info = env.last()
        # print(reward)

        if reward == 1 and j % 2 == 0:
            wins += 1
        elif reward == -1 and j % 2 == 0:
            losses += 1
        j += 1
        if termination or truncation:
            action = None
        else:
            action = agent.get_action(observation)
    
        env.step(action)
        
print(f'player1 wins {wins} lose {losses} games from {games_n} games')       
env.close()
# Out:
# player1 wins 674 lose 200 games from 1000 games

# %% [raw]
# player1 wins 726 lose 90 games from 1000 games - последний полученный результат. Видно, что стратегия обучилась играть и выигрывает с большим заделом у рандомной стратегии.

# %% [markdown]
# ## Задача решена
